# %% [markdown]
# # Brain Age Regression

# %%
# Import all libraries needed for the exploration

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd #this is how we usually import pandas
import numpy as np #this is how we usually import numpy
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import tables # pytables is needed to read and write hdf5 files
import openpyxl # is used to read and write MS Excel files

import xgboost
import math
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn import tree, linear_model
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

# Enable inline plotting
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-15e40bfc16dc> in <module>()
#       7 import sys #only needed to determine Python version number
#       8 import matplotlib #only needed to determine Matplotlib version number
# ----> 9 import tables # pytables is needed to read and write hdf5 files
#      10 import openpyxl # is used to read and write MS Excel files
#      11
#
# ModuleNotFoundError: No module named 'tables'

# %%
# Supress some warnings:
import warnings
warnings.filterwarnings('ignore')

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Numpy version ' + np.__version__)
print('Matplotlib version ' + matplotlib.__version__)
print('Seaborn version ' + sns.__version__)
# Out:
# Python version 3.7.6 (default, Jan  8 2020, 19:59:22)
# [GCC 7.3.0]
# Pandas version 0.25.3
# Numpy version 1.17.4
# Matplotlib version 3.1.1
# Seaborn version 0.9.0

# %% [markdown]
# ## Training data

# %%
data = pd.read_csv('../data/train.csv')

# %% [markdown]
# ### Explore the data

# %%
# Check the number of data points in the data set
print('No observations:', len(data))
# Check the number of features in the data set
print('No variables:', len(data.columns))
# Check the data types
print(data.dtypes.unique())
# Out:
# No observations: 1874
# No variables: 150
# [dtype('int64') dtype('O') dtype('float64')]

# %%
data.shape
# Out:
# (1874, 150)

# %%
data.columns
# Out:
# Index(['SubjectID', 'Source', 'ID', 'Sex', 'Height', 'Weight', 'FieldStrength',
#        'Handedness', 'Measure:volume', 'Left-Lateral-Ventricle',
#        ...
#        'rh_superiortemporal_thickness', 'rh_supramarginal_thickness',
#        'rh_frontalpole_thickness', 'rh_temporalpole_thickness',
#        'rh_transversetemporal_thickness', 'rh_insula_thickness',
#        'rh_MeanThickness_thickness', 'BrainSegVolNotVent', 'eTIV_y', 'Age'],
#       dtype='object', length=150)

# %%
for i, col in enumerate(data.columns, start=0):
    print(i, col)
# Out:
# 0 SubjectID
# 1 Source
# 2 ID
# 3 Sex
# 4 Height
# 5 Weight
# 6 FieldStrength
# 7 Handedness
# 8 Measure:volume
# 9 Left-Lateral-Ventricle
# 10 Left-Inf-Lat-Vent
# 11 Left-Cerebellum-White-Matter
# 12 Left-Cerebellum-Cortex
# 13 Left-Thalamus-Proper
# 14 Left-Caudate
# 15 Left-Putamen
# 16 Left-Pallidum
# 17 3rd-Ventricle
# 18 4th-Ventricle
# 19 Brain-Stem
# 20 Left-Hippocampus
# 21 Left-Amygdala
# 22 CSF
# 23 Left-Accumbens-area
# 24 Left-VentralDC
# 25 Left-vessel
# 26 Left-choroid-plexus
# 27 Right-Lateral-Ventricle
# 28 Right-Inf-Lat-Vent
# 29 Right-Cerebellum-White-Matter
# 30 Right-Cerebellum-Cortex
# 31 Right-Thalamus-Proper
# 32 Right-Caudate
# 33 Right-Putamen
# 34 Right-Pallidum
# 35 Right-Hippocampus
# 36 Right-Amygdala
# 37 Right-Accumbens-area
# 38 Right-VentralDC
# 39 Right-vessel
# 40 Right-choroid-plexus
# 41 5th-Ventricle
# 42 WM-hypointensities
# 43 Left-WM-hypointensities
# 44 Right-WM-hypointensities
# 45 non-WM-hypointensities
# 46 Left-non-WM-hypointensities
# 47 Right-non-WM-hypointensities
# 48 Optic-Chiasm
# 49 CC_Posterior
# 50 CC_Mid_Posterior
# 51 CC_Central
# 52 CC_Mid_Anterior
# 53 CC_Anterior
# 54 BrainSegVol
# 55 BrainSegVolNotVent_x
# 56 BrainSegVolNotVentSurf
# 57 lhCortexVol
# 58 rhCortexVol
# 59 CortexVol
# 60 lhCerebralWhiteMatterVol
# 61 rhCerebralWhiteMatterVol
# 62 CerebralWhiteMatterVol
# 63 SubCortGrayVol
# 64 TotalGrayVol
# 65 SupraTentorialVol
# 66 SupraTentorialVolNotVent
# 67 SupraTentorialVolNotVentVox
# 68 MaskVol
# 69 BrainSegVol-to-eTIV
# 70 MaskVol-to-eTIV
# 71 lhSurfaceHoles
# 72 rhSurfaceHoles
# 73 SurfaceHoles
# 74 EstimatedTotalIntraCranialVol
# 75 lh_bankssts_thickness
# 76 lh_caudalanteriorcingulate_thickness
# 77 lh_caudalmiddlefrontal_thickness
# 78 lh_cuneus_thickness
# 79 lh_entorhinal_thickness
# 80 lh_fusiform_thickness
# 81 lh_inferiorparietal_thickness
# 82 lh_inferiortemporal_thickness
# 83 lh_isthmuscingulate_thickness
# 84 lh_lateraloccipital_thickness
# 85 lh_lateralorbitofrontal_thickness
# 86 lh_lingual_thickness
# 87 lh_medialorbitofrontal_thickness
# 88 lh_middletemporal_thickness
# 89 lh_parahippocampal_thickness
# 90 lh_paracentral_thickness
# 91 lh_parsopercularis_thickness
# 92 lh_parsorbitalis_thickness
# 93 lh_parstriangularis_thickness
# 94 lh_pericalcarine_thickness
# 95 lh_postcentral_thickness
# 96 lh_posteriorcingulate_thickness
# 97 lh_precentral_thickness
# 98 lh_precuneus_thickness
# 99 lh_rostralanteriorcingulate_thickness
# 100 lh_rostralmiddlefrontal_thickness
# 101 lh_superiorfrontal_thickness
# 102 lh_superiorparietal_thickness
# 103 lh_superiortemporal_thickness
# 104 lh_supramarginal_thickness
# 105 lh_frontalpole_thickness
# 106 lh_temporalpole_thickness
# 107 lh_transversetemporal_thickness
# 108 lh_insula_thickness
# 109 lh_MeanThickness_thickness
# 110 BrainSegVolNotVent_y
# 111 eTIV_x
# 112 rh_bankssts_thickness
# 113 rh_caudalanteriorcingulate_thickness
# 114 rh_caudalmiddlefrontal_thickness
# 115 rh_cuneus_thickness
# 116 rh_entorhinal_thickness
# 117 rh_fusiform_thickness
# 118 rh_inferiorparietal_thickness
# 119 rh_inferiortemporal_thickness
# 120 rh_isthmuscingulate_thickness
# 121 rh_lateraloccipital_thickness
# 122 rh_lateralorbitofrontal_thickness
# 123 rh_lingual_thickness
# 124 rh_medialorbitofrontal_thickness
# 125 rh_middletemporal_thickness
# 126 rh_parahippocampal_thickness
# 127 rh_paracentral_thickness
# 128 rh_parsopercularis_thickness
# 129 rh_parsorbitalis_thickness
# 130 rh_parstriangularis_thickness
# 131 rh_pericalcarine_thickness
# 132 rh_postcentral_thickness
# 133 rh_posteriorcingulate_thickness
# 134 rh_precentral_thickness
# 135 rh_precuneus_thickness
# 136 rh_rostralanteriorcingulate_thickness
# 137 rh_rostralmiddlefrontal_thickness
# 138 rh_superiorfrontal_thickness
# 139 rh_superiorparietal_thickness
# 140 rh_superiortemporal_thickness
# 141 rh_supramarginal_thickness
# 142 rh_frontalpole_thickness
# 143 rh_temporalpole_thickness
# 144 rh_transversetemporal_thickness
# 145 rh_insula_thickness
# 146 rh_MeanThickness_thickness
# 147 BrainSegVolNotVent
# 148 eTIV_y
# 149 Age

# %%
# We may have some categorical features, let's check them
data.select_dtypes(include=['O']).columns.tolist()
# Out:
# ['Source', 'ID', 'Sex', 'FieldStrength']

# %%
# Check any number of columns with NaN
print(data.isnull().any().sum(), ' / ', len(data.columns))
# Check number of data points with any NaN
print(data.isnull().any(axis=1).sum(), ' / ', len(data))
# Out:
# 5  /  150
# 1874  /  1874

# %% [markdown]
# ### Select features and targets

# %%
features = data.iloc[:,9:-1].columns.tolist()
target = data.iloc[:,-1].name

# %%
all_lh_features = [
 'CSF', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'EstimatedTotalIntraCranialVol',
 'Left-Lateral-Ventricle',
 'Left-Inf-Lat-Vent',
 'Left-Cerebellum-White-Matter',
 'Left-Cerebellum-Cortex',
 'Left-Thalamus-Proper',
 'Left-Caudate',
 'Left-Putamen',
 'Left-Pallidum',
 'Left-Hippocampus',
 'Left-Amygdala',
 'Left-Accumbens-area',
 'Left-VentralDC',
 'Left-vessel',
 'Left-choroid-plexus',
 'Left-WM-hypointensities',
 'Left-non-WM-hypointensities',
 'lhCortexVol',
 'lhCerebralWhiteMatterVol',            
 'lhSurfaceHoles',  
 'lh.aparc.thickness',
 'lh_bankssts_thickness',
 'lh_caudalanteriorcingulate_thickness',
 'lh_caudalmiddlefrontal_thickness',
 'lh_cuneus_thickness',
 'lh_entorhinal_thickness',
 'lh_fusiform_thickness',
 'lh_inferiorparietal_thickness',
 'lh_inferiortemporal_thickness',
 'lh_isthmuscingulate_thickness',
 'lh_lateraloccipital_thickness',
 'lh_lateralorbitofrontal_thickness',
 'lh_lingual_thickness',
 'lh_medialorbitofrontal_thickness',
 'lh_middletemporal_thickness',
 'lh_parahippocampal_thickness',
 'lh_paracentral_thickness',
 'lh_parsopercularis_thickness',
 'lh_parsorbitalis_thickness',
 'lh_parstriangularis_thickness',
 'lh_pericalcarine_thickness',
 'lh_postcentral_thickness',
 'lh_posteriorcingulate_thickness',
 'lh_precentral_thickness',
 'lh_precuneus_thickness',
 'lh_rostralanteriorcingulate_thickness',
 'lh_rostralmiddlefrontal_thickness',
 'lh_superiorfrontal_thickness',
 'lh_superiorparietal_thickness',
 'lh_superiortemporal_thickness',
 'lh_supramarginal_thickness',
 'lh_frontalpole_thickness',
 'lh_temporalpole_thickness',
 'lh_transversetemporal_thickness',
 'lh_insula_thickness',
 'lh_MeanThickness_thickness'
 ]

# %%
# Make rh_ and Right- names (base on LHs)

# List comprehensions
rh_names = [w.replace('lh_', 'rh_') for w in all_lh_features]
Right_names = [w.replace('Left-', 'Right-') for w in rh_names]
most_rh_names = [w.replace('lhC', 'rhC') for w in Right_names]
all_rh_names = [w.replace('lhS', 'rhS') for w in most_rh_names]
all_rh_features = [w.replace('lh.', 'rh.') for w in all_rh_names]
all_rh_features
# Out:
# ['CSF',
#  'CC_Posterior',
#  'CC_Mid_Posterior',
#  'CC_Central',
#  'CC_Mid_Anterior',
#  'CC_Anterior',
#  'EstimatedTotalIntraCranialVol',
#  'Right-Lateral-Ventricle',
#  'Right-Inf-Lat-Vent',
#  'Right-Cerebellum-White-Matter',
#  'Right-Cerebellum-Cortex',
#  'Right-Thalamus-Proper',
#  'Right-Caudate',
#  'Right-Putamen',
#  'Right-Pallidum',
#  'Right-Hippocampus',
#  'Right-Amygdala',
#  'Right-Accumbens-area',
#  'Right-VentralDC',
#  'Right-vessel',
#  'Right-choroid-plexus',
#  'Right-WM-hypointensities',
#  'Right-non-WM-hypointensities',
#  'rhCortexVol',
#  'rhCerebralWhiteMatterVol',
#  'rhSurfaceHoles',
#  'rh.aparc.thickness',
#  'rh_bankssts_thickness',
#  'rh_caudalanteriorcingulate_thickness',
#  'rh_caudalmiddlefrontal_thickness',
#  'rh_cuneus_thickness',
#  'rh_entorhinal_thickness',
#  'rh_fusiform_thickness',
#  'rh_inferiorparietal_thickness',
#  'rh_inferiortemporal_thickness',
#  'rh_isthmuscingulate_thickness',
#  'rh_lateraloccipital_thickness',
#  'rh_lateralorbitofrontal_thickness',
#  'rh_lingual_thickness',
#  'rh_medialorbitofrontal_thickness',
#  'rh_middletemporal_thickness',
#  'rh_parahippocampal_thickness',
#  'rh_paracentral_thickness',
#  'rh_parsopercularis_thickness',
#  'rh_parsorbitalis_thickness',
#  'rh_parstriangularis_thickness',
#  'rh_pericalcarine_thickness',
#  'rh_postcentral_thickness',
#  'rh_posteriorcingulate_thickness',
#  'rh_precentral_thickness',
#  'rh_precuneus_thickness',
#  'rh_rostralanteriorcingulate_thickness',
#  'rh_rostralmiddlefrontal_thickness',
#  'rh_superiorfrontal_thickness',
#  'rh_superiorparietal_thickness',
#  'rh_superiortemporal_thickness',
#  'rh_supramarginal_thickness',
#  'rh_frontalpole_thickness',
#  'rh_temporalpole_thickness',
#  'rh_transversetemporal_thickness',
#  'rh_insula_thickness',
#  'rh_MeanThickness_thickness']

# %%
data_lh = data[all_lh_features]
pd.DataFrame(data_lh.count())
# Out:
#                                           0
# CSF                                    1085
# CC_Posterior                           1085
# CC_Mid_Posterior                       1085
# CC_Central                             1085
# CC_Mid_Anterior                        1085
# CC_Anterior                            1085
# EstimatedTotalIntraCranialVol          1085
# Left-Lateral-Ventricle                 1085
# Left-Inf-Lat-Vent                      1085
# Left-Cerebellum-White-Matter           1085
# Left-Cerebellum-Cortex                 1085
# Left-Thalamus-Proper                   1085
# Left-Caudate                           1085
# Left-Putamen                           1085
# Left-Pallidum                          1085
# Left-Hippocampus                       1085
# Left-Amygdala                          1085
# Left-Accumbens-area                    1085
# Left-VentralDC                         1085
# Left-vessel                            1085
# Left-choroid-plexus                    1085
# Left-WM-hypointensities                1085
# Left-non-WM-hypointensities            1085
# lhCortexVol                            1085
# lhCerebralWhiteMatterVol               1085
# lhSurfaceHoles                         1085
# lh.aparc.thickness                     1085
# lh_bankssts_thickness                  1085
# lh_caudalanteriorcingulate_thickness   1085
# lh_caudalmiddlefrontal_thickness       1085
# ...                                     ...
# lh_fusiform_thickness                  1085
# lh_inferiorparietal_thickness          1085
# lh_inferiortemporal_thickness          1085
# lh_isthmuscingulate_thickness          1085
# lh_lateraloccipital_thickness          1085
# lh_lateralorbitofrontal_thickness      1085
# lh_lingual_thickness                   1085
# lh_medialorbitofrontal_thickness       1085
# lh_middletemporal_thickness            1085
# lh_parahippocampal_thickness           1085
# lh_paracentral_thickness               1085
# lh_parsopercularis_thickness           1085
# lh_parsorbitalis_thickness             1085
# lh_parstriangularis_thickness          1085
# lh_pericalcarine_thickness             1085
# lh_postcentral_thickness               1085
# lh_posteriorcingulate_thickness        1085
# lh_precentral_thickness                1085
# lh_precuneus_thickness                 1085
# lh_rostralanteriorcingulate_thickness  1085
# lh_rostralmiddlefrontal_thickness      1085
# lh_superiorfrontal_thickness           1085
# lh_superiorparietal_thickness          1085
# lh_superiortemporal_thickness          1085
# lh_supramarginal_thickness             1085
# lh_frontalpole_thickness               1085
# lh_temporalpole_thickness              1085
# lh_transversetemporal_thickness        1085
# lh_insula_thickness                    1085
# lh_MeanThickness_thickness             1085
#
# [62 rows x 1 columns]

# %%
data_lh.describe().T
# Out:
#                                         count          mean            std  \
# CSF                                    1085.0  1.032723e+03     275.511828
# CC_Posterior                           1085.0  9.987616e+02     165.006387
# CC_Mid_Posterior                       1085.0  5.644137e+02     133.126229
# CC_Central                             1085.0  6.605299e+02     182.178230
# CC_Mid_Anterior                        1085.0  6.463947e+02     178.891557
# CC_Anterior                            1085.0  8.903859e+02     158.324487
# EstimatedTotalIntraCranialVol          1085.0  1.515452e+06  165943.653773
# Left-Lateral-Ventricle                 1085.0  8.635934e+03    5515.628037
# Left-Inf-Lat-Vent                      1085.0  3.151976e+02     206.390677
# Left-Cerebellum-White-Matter           1085.0  1.519431e+04    2548.795235
# Left-Cerebellum-Cortex                 1085.0  5.400942e+04    6687.248117
# Left-Thalamus-Proper                   1085.0  7.692726e+03    1009.773341
# Left-Caudate                           1085.0  3.398497e+03     493.541222
# Left-Putamen                           1085.0  4.821019e+03     730.769654
# Left-Pallidum                          1085.0  2.022324e+03     265.444356
# Left-Hippocampus                       1085.0  4.030630e+03     437.061473
# Left-Amygdala                          1085.0  1.562254e+03     232.339195
# Left-Accumbens-area                    1085.0  4.293923e+02     109.868662
# Left-VentralDC                         1085.0  4.086382e+03     494.927863
# Left-vessel                            1085.0  2.805456e+01      26.742119
# Left-choroid-plexus                    1085.0  4.674794e+02     230.346006
# Left-WM-hypointensities                1085.0  0.000000e+00       0.000000
# Left-non-WM-hypointensities            1085.0  0.000000e+00       0.000000
# lhCortexVol                            1085.0  2.363720e+05   32644.405790
# lhCerebralWhiteMatterVol               1085.0  2.308130e+05   29377.075012
# lhSurfaceHoles                         1085.0  4.417972e+01      27.302122
# lh_bankssts_thickness                  1085.0  2.508571e+00       0.188955
# lh_caudalanteriorcingulate_thickness   1085.0  2.700383e+00       0.264987
# lh_caudalmiddlefrontal_thickness       1085.0  2.616787e+00       0.186208
# lh_cuneus_thickness                    1085.0  1.854182e+00       0.157113
# ...                                       ...           ...            ...
# lh_fusiform_thickness                  1085.0  2.747916e+00       0.164965
# lh_inferiorparietal_thickness          1085.0  2.496533e+00       0.152943
# lh_inferiortemporal_thickness          1085.0  2.824749e+00       0.151881
# lh_isthmuscingulate_thickness          1085.0  2.390481e+00       0.194928
# lh_lateraloccipital_thickness          1085.0  2.198961e+00       0.140064
# lh_lateralorbitofrontal_thickness      1085.0  2.710128e+00       0.159092
# lh_lingual_thickness                   1085.0  1.959378e+00       0.146109
# lh_medialorbitofrontal_thickness       1085.0  2.501132e+00       0.179151
# lh_middletemporal_thickness            1085.0  2.873102e+00       0.173504
# lh_parahippocampal_thickness           1085.0  2.735071e+00       0.298453
# lh_paracentral_thickness               1085.0  2.416563e+00       0.208875
# lh_parsopercularis_thickness           1085.0  2.612482e+00       0.178784
# lh_parsorbitalis_thickness             1085.0  2.762101e+00       0.214068
# lh_parstriangularis_thickness          1085.0  2.496142e+00       0.174373
# lh_pericalcarine_thickness             1085.0  1.576081e+00       0.157079
# lh_postcentral_thickness               1085.0  2.100215e+00       0.149994
# lh_posteriorcingulate_thickness        1085.0  2.529695e+00       0.192362
# lh_precentral_thickness                1085.0  2.562234e+00       0.193120
# lh_precuneus_thickness                 1085.0  2.409100e+00       0.163957
# lh_rostralanteriorcingulate_thickness  1085.0  2.866589e+00       0.234040
# lh_rostralmiddlefrontal_thickness      1085.0  2.446345e+00       0.154947
# lh_superiorfrontal_thickness           1085.0  2.799465e+00       0.204794
# lh_superiorparietal_thickness          1085.0  2.243310e+00       0.155031
# lh_superiortemporal_thickness          1085.0  2.785446e+00       0.185657
# lh_supramarginal_thickness             1085.0  2.574290e+00       0.163060
# lh_frontalpole_thickness               1085.0  2.839942e+00       0.285817
# lh_temporalpole_thickness              1085.0  3.681482e+00       0.293109
# lh_transversetemporal_thickness        1085.0  2.303040e+00       0.230310
# lh_insula_thickness                    1085.0  2.972150e+00       0.194034
# lh_MeanThickness_thickness             1085.0  2.511837e+00       0.133497
#
#                                                  min           25%  \
# CSF                                       550.900000  8.495000e+02
# CC_Posterior                              259.400000  8.902000e+02
# CC_Mid_Posterior                          115.500000  4.795000e+02
# CC_Central                                255.700000  5.111000e+02
# CC_Mid_Anterior                           247.400000  5.046000e+02
# CC_Anterior                               451.100000  7.865000e+02
# EstimatedTotalIntraCranialVol          955810.846787  1.395718e+06
# Left-Lateral-Ventricle                   2284.700000  5.113900e+03
# Left-Inf-Lat-Vent                          24.600000  1.900000e+02
# Left-Cerebellum-White-Matter             8065.000000  1.358100e+04
# Left-Cerebellum-Cortex                  35166.100000  4.950190e+04
# Left-Thalamus-Proper                     4769.500000  6.968900e+03
# Left-Caudate                             2133.800000  3.054700e+03
# Left-Putamen                             2928.200000  4.301800e+03
# Left-Pallidum                            1327.500000  1.828000e+03
# Left-Hippocampus                         2249.700000  3.752000e+03
# Left-Amygdala                             756.400000  1.390500e+03
# Left-Accumbens-area                       130.000000  3.559000e+02
# Left-VentralDC                           2711.800000  3.752200e+03
# Left-vessel                                 0.000000  1.350000e+01
# Left-choroid-plexus                        64.300000  2.990000e+02
# Left-WM-hypointensities                     0.000000  0.000000e+00
# Left-non-WM-hypointensities                 0.000000  0.000000e+00
# lhCortexVol                            123178.567074  2.124890e+05
# lhCerebralWhiteMatterVol               161385.473134  2.095846e+05
# lhSurfaceHoles                              4.000000  2.500000e+01
# lh_bankssts_thickness                       1.275000  2.401000e+00
# lh_caudalanteriorcingulate_thickness        1.568000  2.532000e+00
# lh_caudalmiddlefrontal_thickness            1.695000  2.489000e+00
# lh_cuneus_thickness                         1.286000  1.741000e+00
# ...                                              ...           ...
# lh_fusiform_thickness                       1.676000  2.646000e+00
# lh_inferiorparietal_thickness               1.634000  2.405000e+00
# lh_inferiortemporal_thickness               1.968000  2.729000e+00
# lh_isthmuscingulate_thickness               1.531000  2.265000e+00
# lh_lateraloccipital_thickness               1.461000  2.102000e+00
# lh_lateralorbitofrontal_thickness           1.783000  2.610000e+00
# lh_lingual_thickness                        1.409000  1.867000e+00
# lh_medialorbitofrontal_thickness            1.610000  2.375000e+00
# lh_middletemporal_thickness                 1.731000  2.769000e+00
# lh_parahippocampal_thickness                1.589000  2.543000e+00
# lh_paracentral_thickness                    1.318000  2.292000e+00
# lh_parsopercularis_thickness                1.547000  2.496000e+00
# lh_parsorbitalis_thickness                  1.599000  2.629000e+00
# lh_parstriangularis_thickness               1.405000  2.377000e+00
# lh_pericalcarine_thickness                  1.034000  1.460000e+00
# lh_postcentral_thickness                    1.459000  1.998000e+00
# lh_posteriorcingulate_thickness             1.496000  2.403000e+00
# lh_precentral_thickness                     1.430000  2.448000e+00
# lh_precuneus_thickness                      1.391000  2.303000e+00
# lh_rostralanteriorcingulate_thickness       1.606000  2.715000e+00
# lh_rostralmiddlefrontal_thickness           1.841000  2.341000e+00
# lh_superiorfrontal_thickness                1.808000  2.659000e+00
# lh_superiorparietal_thickness               1.656000  2.132000e+00
# lh_superiortemporal_thickness               1.658000  2.662000e+00
# lh_supramarginal_thickness                  1.618000  2.468000e+00
# lh_frontalpole_thickness                    1.579000  2.636000e+00
# lh_temporalpole_thickness                   2.289000  3.512000e+00
# lh_transversetemporal_thickness             1.257000  2.156000e+00
# lh_insula_thickness                         1.498000  2.869000e+00
# lh_MeanThickness_thickness                  1.636380  2.422350e+00
#
#                                                 50%           75%  \
# CSF                                    9.899000e+02  1.154000e+03
# CC_Posterior                           9.960000e+02  1.085900e+03
# CC_Mid_Posterior                       5.486000e+02  6.324000e+02
# CC_Central                             6.562000e+02  7.948000e+02
# CC_Mid_Anterior                        6.348000e+02  7.690000e+02
# CC_Anterior                            8.744000e+02  9.783000e+02
# EstimatedTotalIntraCranialVol          1.504274e+06  1.626013e+06
# Left-Lateral-Ventricle                 7.219100e+03  1.039490e+04
# Left-Inf-Lat-Vent                      2.604000e+02  3.873000e+02
# Left-Cerebellum-White-Matter           1.483760e+04  1.637510e+04
# Left-Cerebellum-Cortex                 5.386680e+04  5.827490e+04
# Left-Thalamus-Proper                   7.700600e+03  8.429400e+03
# Left-Caudate                           3.359500e+03  3.724800e+03
# Left-Putamen                           4.769400e+03  5.328600e+03
# Left-Pallidum                          2.014500e+03  2.201600e+03
# Left-Hippocampus                       4.010400e+03  4.310500e+03
# Left-Amygdala                          1.555900e+03  1.719100e+03
# Left-Accumbens-area                    4.216000e+02  4.964000e+02
# Left-VentralDC                         4.056100e+03  4.412400e+03
# Left-vessel                            2.400000e+01  3.550000e+01
# Left-choroid-plexus                    4.238000e+02  5.842000e+02
# Left-WM-hypointensities                0.000000e+00  0.000000e+00
# Left-non-WM-hypointensities            0.000000e+00  0.000000e+00
# lhCortexVol                            2.348239e+05  2.591173e+05
# lhCerebralWhiteMatterVol               2.276044e+05  2.498089e+05
# lhSurfaceHoles                         4.000000e+01  5.800000e+01
# lh_bankssts_thickness                  2.518000e+00  2.631000e+00
# lh_caudalanteriorcingulate_thickness   2.709000e+00  2.871000e+00
# lh_caudalmiddlefrontal_thickness       2.618000e+00  2.754000e+00
# lh_cuneus_thickness                    1.859000e+00  1.961000e+00
# ...                                             ...           ...
# lh_fusiform_thickness                  2.760000e+00  2.864000e+00
# lh_inferiorparietal_thickness          2.504000e+00  2.608000e+00
# lh_inferiortemporal_thickness          2.828000e+00  2.928000e+00
# lh_isthmuscingulate_thickness          2.373000e+00  2.505000e+00
# lh_lateraloccipital_thickness          2.204000e+00  2.300000e+00
# lh_lateralorbitofrontal_thickness      2.704000e+00  2.812000e+00
# lh_lingual_thickness                   1.964000e+00  2.056000e+00
# lh_medialorbitofrontal_thickness       2.497000e+00  2.624000e+00
# lh_middletemporal_thickness            2.884000e+00  2.986000e+00
# lh_parahippocampal_thickness           2.737000e+00  2.937000e+00
# lh_paracentral_thickness               2.432000e+00  2.562000e+00
# lh_parsopercularis_thickness           2.609000e+00  2.742000e+00
# lh_parsorbitalis_thickness             2.762000e+00  2.905000e+00
# lh_parstriangularis_thickness          2.501000e+00  2.626000e+00
# lh_pericalcarine_thickness             1.568000e+00  1.679000e+00
# lh_postcentral_thickness               2.103000e+00  2.209000e+00
# lh_posteriorcingulate_thickness        2.533000e+00  2.663000e+00
# lh_precentral_thickness                2.584000e+00  2.703000e+00
# lh_precuneus_thickness                 2.419000e+00  2.526000e+00
# lh_rostralanteriorcingulate_thickness  2.872000e+00  3.022000e+00
# lh_rostralmiddlefrontal_thickness      2.446000e+00  2.554000e+00
# lh_superiorfrontal_thickness           2.792000e+00  2.952000e+00
# lh_superiorparietal_thickness          2.244000e+00  2.366000e+00
# lh_superiortemporal_thickness          2.797000e+00  2.915000e+00
# lh_supramarginal_thickness             2.585000e+00  2.694000e+00
# lh_frontalpole_thickness               2.847000e+00  3.022000e+00
# lh_temporalpole_thickness              3.695000e+00  3.879000e+00
# lh_transversetemporal_thickness        2.314000e+00  2.456000e+00
# lh_insula_thickness                    2.979000e+00  3.102000e+00
# lh_MeanThickness_thickness             2.514060e+00  2.612490e+00
#
#                                                 max
# CSF                                    3.135600e+03
# CC_Posterior                           1.824100e+03
# CC_Mid_Posterior                       1.447200e+03
# CC_Central                             1.289500e+03
# CC_Mid_Anterior                        1.294700e+03
# CC_Anterior                            1.650500e+03
# EstimatedTotalIntraCranialVol          1.978181e+06
# Left-Lateral-Ventricle                 5.612140e+04
# Left-Inf-Lat-Vent                      2.396500e+03
# Left-Cerebellum-White-Matter           3.164460e+04
# Left-Cerebellum-Cortex                 7.775480e+04
# Left-Thalamus-Proper                   1.098410e+04
# Left-Caudate                           5.682100e+03
# Left-Putamen                           7.203300e+03
# Left-Pallidum                          2.979200e+03
# Left-Hippocampus                       5.557500e+03
# Left-Amygdala                          2.329900e+03
# Left-Accumbens-area                    8.073000e+02
# Left-VentralDC                         5.880000e+03
# Left-vessel                            4.335000e+02
# Left-choroid-plexus                    1.794400e+03
# Left-WM-hypointensities                0.000000e+00
# Left-non-WM-hypointensities            0.000000e+00
# lhCortexVol                            3.370414e+05
# lhCerebralWhiteMatterVol               3.359539e+05
# lhSurfaceHoles                         3.420000e+02
# lh_bankssts_thickness                  3.139000e+00
# lh_caudalanteriorcingulate_thickness   3.569000e+00
# lh_caudalmiddlefrontal_thickness       3.120000e+00
# lh_cuneus_thickness                    2.306000e+00
# ...                                             ...
# lh_fusiform_thickness                  3.191000e+00
# lh_inferiorparietal_thickness          2.956000e+00
# lh_inferiortemporal_thickness          3.330000e+00
# lh_isthmuscingulate_thickness          3.068000e+00
# lh_lateraloccipital_thickness          2.602000e+00
# lh_lateralorbitofrontal_thickness      3.415000e+00
# lh_lingual_thickness                   2.535000e+00
# lh_medialorbitofrontal_thickness       3.098000e+00
# lh_middletemporal_thickness            3.285000e+00
# lh_parahippocampal_thickness           3.709000e+00
# lh_paracentral_thickness               2.994000e+00
# lh_parsopercularis_thickness           3.081000e+00
# lh_parsorbitalis_thickness             3.462000e+00
# lh_parstriangularis_thickness          3.191000e+00
# lh_pericalcarine_thickness             2.380000e+00
# lh_postcentral_thickness               2.541000e+00
# lh_posteriorcingulate_thickness        3.103000e+00
# lh_precentral_thickness                3.100000e+00
# lh_precuneus_thickness                 2.807000e+00
# lh_rostralanteriorcingulate_thickness  3.473000e+00
# lh_rostralmiddlefrontal_thickness      2.879000e+00
# lh_superiorfrontal_thickness           3.402000e+00
# lh_superiorparietal_thickness          2.690000e+00
# lh_superiortemporal_thickness          3.248000e+00
# lh_supramarginal_thickness             2.973000e+00
# lh_frontalpole_thickness               3.677000e+00
# lh_temporalpole_thickness              4.462000e+00
# lh_transversetemporal_thickness        3.040000e+00
# lh_insula_thickness                    3.546000e+00
# lh_MeanThickness_thickness             2.838170e+00
#
# [61 rows x 8 columns]

# %%
dropcolumns = [
    'EstimatedTotalIntraCranialVol',
    'CSF', 
    'CC_Posterior', 
    'CC_Mid_Posterior', 
    'CC_Central', 
    'CC_Mid_Anterior', 
    'CC_Anterior'   
]

df_lh = data_lh.drop(dropcolumns, axis=1)
df_lh
# Out:
#       Left-Lateral-Ventricle  Left-Inf-Lat-Vent  Left-Cerebellum-White-Matter  \
# 0                     5968.4              212.0                       12717.4
# 1                    12256.1              241.9                       15603.7
# 2                     4764.0              202.1                       13745.1
# 3                    10770.0              532.2                       13814.3
# 4                     6773.7              517.0                       15662.8
# 5                     7624.0              242.9                       14844.7
# 6                     6704.6              194.1                       15954.4
# 7                     6180.0              145.6                       15200.8
# 8                     8390.7              164.2                       14077.6
# 9                     7342.8              334.8                       14736.9
# 10                   10416.7              256.5                       17613.3
# 11                    8892.5              122.1                       19302.6
# 12                    6655.4              227.9                       14165.2
# 13                    5816.1              327.3                       15100.4
# 14                    9348.1              829.8                       14151.4
# 15                    7994.5              235.9                       13164.3
# 16                   22741.0              745.7                       14346.6
# 17                    5546.7              575.8                       12804.8
# 18                    7098.4              229.1                       16903.8
# 19                   12694.1              247.7                       19202.5
# 20                    7076.1              332.3                       16659.9
# 21                   10020.5              717.3                       12443.8
# 22                   11683.3              482.4                       16375.1
# 23                    4122.2              151.2                       14239.1
# 24                    9176.7              222.6                       17823.1
# 25                   12420.5              116.2                       20619.7
# 26                    3973.4              282.3                       17570.2
# 27                    8428.9              272.7                       14289.7
# 28                    7773.1              180.4                       21128.7
# 29                    6399.4              326.9                       15673.5
# ...                      ...                ...                           ...
# 1055                  6205.4              207.6                       14405.2
# 1056                  3073.9              302.5                       12247.5
# 1057                  9531.4              330.5                       11820.8
# 1058                  7055.4              166.9                       16501.9
# 1059                  7406.0              232.9                       13739.5
# 1060                  3358.6              397.6                       15427.5
# 1061                 12877.7              325.7                       15521.4
# 1062                  8967.1              250.7                       14420.4
# 1063                  3688.8              291.8                       17978.8
# 1064                  4416.0              285.1                       11303.4
# 1065                 13131.0              431.2                       12268.4
# 1066                 12462.9              251.9                       17151.1
# 1067                 12766.4              189.8                       13015.9
# 1068                  3231.1              166.3                       15962.8
# 1069                 15440.8              599.3                       17908.4
# 1070                  9592.6              270.0                       17798.1
# 1071                  4403.9              249.5                       16405.4
# 1072                  4263.8              389.1                       11817.5
# 1073                  6873.2              122.3                       11060.9
# 1074                  3987.4              390.2                       14343.5
# 1075                  4663.7              148.5                       12684.8
# 1076                  3609.5              181.7                       15779.9
# 1077                  8359.8              106.4                       18876.8
# 1078                 36817.0             1901.7                       13508.8
# 1079                  7715.7              507.0                       12685.3
# 1080                  3794.7               31.7                       19280.4
# 1081                 17935.0              473.7                       16101.9
# 1082                  3116.1               98.7                       14541.8
# 1083                  9992.8              412.2                       15710.0
# 1084                  7367.8              138.2                       10804.7
#
#       Left-Cerebellum-Cortex  Left-Thalamus-Proper  Left-Caudate  \
# 0                    54979.7                8170.7        3773.4
# 1                    50793.1                8513.6        4153.9
# 2                    44080.0                7312.0        3320.8
# 3                    50342.0                7367.5        2726.2
# 4                    54779.1                7156.6        3357.3
# 5                    58079.1                8214.1        2806.9
# 6                    59217.9                8339.7        3241.6
# 7                    63160.4                8401.1        3298.0
# 8                    53929.8                6794.8        2736.6
# 9                    55986.5                7323.9        3312.5
# 10                   44648.8                7361.8        3486.0
# 11                   52296.0                7628.7        2674.3
# 12                   54341.5                7450.1        3301.0
# 13                   58062.7                8404.8        3805.0
# 14                   55293.7                6956.3        3933.6
# 15                   56410.0                7433.2        4283.8
# 16                   41041.2                6578.3        3521.6
# 17                   45122.7                6243.8        2657.8
# 18                   57736.3                7840.8        3645.4
# 19                   49949.0                7065.3        2489.1
# 20                   59776.9                8729.0        3891.8
# 21                   50540.8                6390.6        2687.8
# 22                   62609.8                8208.7        4677.6
# 23                   53278.8                7961.6        3033.9
# 24                   67473.4                8100.6        3822.2
# 25                   56411.8                9070.1        3750.9
# 26                   61128.0                8668.1        3691.9
# 27                   63336.0                8166.4        3724.4
# 28                   44126.3                7862.6        3465.6
# 29                   66235.4                8429.4        3381.9
# ...                      ...                   ...           ...
# 1055                 48871.5                5907.3        2904.4
# 1056                 47418.6                6705.3        3108.3
# 1057                 52387.4                6514.2        3200.7
# 1058                 62375.7                9098.4        4080.4
# 1059                 48073.5                6870.7        3128.4
# 1060                 58785.0                8891.4        3158.6
# 1061                 64832.5                9702.1        4439.7
# 1062                 44164.8                6242.3        3161.0
# 1063                 58796.6                9220.3        3443.1
# 1064                 46295.2                6874.4        2568.7
# 1065                 51634.7                6525.2        2898.0
# 1066                 59416.0                8480.7        3270.9
# 1067                 54876.3                7039.3        3465.3
# 1068                 52711.7                6699.1        2582.9
# 1069                 47064.1                6785.2        3214.9
# 1070                 59480.1                8917.4        3861.6
# 1071                 57238.5               10196.3        4070.6
# 1072                 49840.7                7162.9        2600.5
# 1073                 43546.3                5965.7        3301.2
# 1074                 58095.0                9398.9        3171.1
# 1075                 45381.9                7595.8        3993.1
# 1076                 53250.3                8119.9        3543.6
# 1077                 53113.2                8447.0        3135.4
# 1078                 52671.7                6545.3        3836.3
# 1079                 47534.9                6359.3        3153.8
# 1080                 58613.7                8924.1        3090.4
# 1081                 48996.3                6542.0        3430.0
# 1082                 58064.3                6351.6        2885.1
# 1083                 54893.8                6730.6        3002.5
# 1084                 47892.4                5998.0        2316.2
#
#       Left-Putamen  Left-Pallidum  Left-Hippocampus  Left-Amygdala  ...  \
# 0           5204.9         1956.4            4150.9         1515.2  ...
# 1           5317.9         2330.4            3971.8         1692.1  ...
# 2           4137.5         1797.2            3465.7         1377.4  ...
# 3           4771.3         2122.2            4046.3         1476.0  ...
# 4           4940.3         2010.9            4109.7         1435.1  ...
# 5           4084.5         1999.0            4245.7         1607.9  ...
# 6           5318.9         2165.5            4349.9         1732.6  ...
# 7           4838.4         2035.7            4224.4         1487.2  ...
# 8           4461.0         1881.6            4606.9         1760.1  ...
# 9           3421.6         1908.2            4574.3         1655.2  ...
# 10          4595.8         1996.4            3728.0         1447.8  ...
# 11          4308.9         2208.3            3809.8         1532.8  ...
# 12          5814.3         1964.0            3959.4         1710.9  ...
# 13          5318.0         2199.4            4087.8         1363.8  ...
# 14          4822.2         2125.5            3835.2         1287.4  ...
# 15          5728.1         2200.2            3811.3         1565.4  ...
# 16          4990.4         1958.1            3699.9         1776.7  ...
# 17          3458.9         1589.5            3250.4         1196.6  ...
# 18          5588.2         2238.8            4326.7         1839.7  ...
# 19          3760.5         1408.4            3342.6         1167.1  ...
# 20          4060.1         1854.3            4959.4         1965.1  ...
# 21          3744.0         1786.9            4131.1         1376.5  ...
# 22          6233.1         2259.4            4531.9         2194.4  ...
# 23          4059.6         1931.9            4101.7         1438.4  ...
# 24          5233.8         2046.1            5020.7         1944.5  ...
# 25          5169.9         2373.1            4227.6         1709.8  ...
# 26          6357.0         2317.8            4335.3         1888.1  ...
# 27          5537.5         2188.3            4600.4         1883.5  ...
# 28          4942.3         1996.3            4230.1         1840.4  ...
# 29          5266.6         2067.8            4309.2         1692.6  ...
# ...            ...            ...               ...            ...  ...
# 1055        3622.7         1722.8            2859.6          926.6  ...
# 1056        4281.8         1739.5            4094.7         1465.7  ...
# 1057        4518.7         1991.8            3736.5         1390.5  ...
# 1058        5179.6         2360.0            4534.0         1610.3  ...
# 1059        4026.6         1923.2            4116.9         1669.1  ...
# 1060        5056.6         1998.0            3976.2         1718.1  ...
# 1061        6186.9         2406.0            4928.3         1890.8  ...
# 1062        3886.6         1792.7            3441.9         1266.9  ...
# 1063        4963.5         2200.2            4173.5         1821.2  ...
# 1064        4674.2         1832.1            4314.5         1739.8  ...
# 1065        3996.0         1616.1            3433.4         1276.5  ...
# 1066        4797.4         2160.5            4713.4         1532.8  ...
# 1067        4294.9         2094.6            4107.8         1363.0  ...
# 1068        4213.2         1806.1            4047.1         1366.1  ...
# 1069        4357.9         2130.2            3601.4         1322.2  ...
# 1070        5736.5         2387.6            4547.8         1918.0  ...
# 1071        6620.4         2441.7            4641.4         1622.2  ...
# 1072        4431.6         1645.3            3485.1         1203.8  ...
# 1073        4725.9         2107.4            3713.8         1384.1  ...
# 1074        5328.6         2134.9            4779.8         1742.8  ...
# 1075        5237.4         2130.7            4020.0         1541.1  ...
# 1076        4952.9         2026.4            3800.6         1505.2  ...
# 1077        4361.9         2246.3            4756.9         1630.0  ...
# 1078        4922.2         1979.6            3875.1         1334.3  ...
# 1079        4556.5         1980.8            3869.6         1293.0  ...
# 1080        5180.6         2285.0            4595.9         1527.1  ...
# 1081        3995.2         2043.6            3513.4         1403.0  ...
# 1082        3963.1         1695.5            3680.0         1393.1  ...
# 1083        3941.9         1888.4            3547.3         1340.1  ...
# 1084        3514.0         1555.2            3454.2         1409.7  ...
#
#       lh_rostralmiddlefrontal_thickness  lh_superiorfrontal_thickness  \
# 0                                 2.560                         2.924
# 1                                 2.530                         2.981
# 2                                 2.551                         2.882
# 3                                 2.418                         2.516
# 4                                 2.302                         2.505
# 5                                 2.467                         2.677
# 6                                 2.442                         2.750
# 7                                 2.363                         2.767
# 8                                 2.467                         2.784
# 9                                 2.705                         2.932
# 10                                2.415                         2.821
# 11                                2.405                         2.864
# 12                                2.551                         2.994
# 13                                2.669                         3.024
# 14                                2.438                         2.534
# 15                                2.421                         2.705
# 16                                2.194                         2.650
# 17                                2.414                         2.760
# 18                                2.680                         3.023
# 19                                2.479                         2.737
# 20                                2.378                         2.594
# 21                                2.359                         2.716
# 22                                2.577                         3.110
# 23                                2.421                         2.599
# 24                                2.669                         3.028
# 25                                2.716                         2.845
# 26                                2.521                         2.973
# 27                                2.678                         2.991
# 28                                2.503                         3.007
# 29                                2.618                         2.994
# ...                                 ...                           ...
# 1055                              2.496                         2.838
# 1056                              2.421                         2.762
# 1057                              2.302                         2.577
# 1058                              2.606                         3.074
# 1059                              2.497                         2.898
# 1060                              2.621                         3.001
# 1061                              2.680                         3.011
# 1062                              2.383                         2.776
# 1063                              2.559                         2.992
# 1064                              2.736                         2.955
# 1065                              2.411                         2.583
# 1066                              2.400                         2.789
# 1067                              2.363                         2.550
# 1068                              2.442                         2.815
# 1069                              2.463                         2.793
# 1070                              2.262                         2.684
# 1071                              2.572                         3.003
# 1072                              2.534                         2.638
# 1073                              2.322                         2.734
# 1074                              2.660                         2.929
# 1075                              2.551                         2.899
# 1076                              2.679                         2.905
# 1077                              2.510                         2.649
# 1078                              2.544                         2.907
# 1079                              2.222                         2.504
# 1080                              2.408                         2.603
# 1081                              2.164                         2.458
# 1082                              2.324                         2.646
# 1083                              2.154                         2.401
# 1084                              2.332                         2.665
#
#       lh_superiorparietal_thickness  lh_superiortemporal_thickness  \
# 0                             2.379                          2.953
# 1                             2.333                          2.817
# 2                             2.286                          2.790
# 3                             2.180                          2.780
# 4                             2.062                          2.579
# 5                             1.995                          2.899
# 6                             2.209                          2.693
# 7                             2.024                          2.956
# 8                             2.118                          2.687
# 9                             2.206                          2.896
# 10                            2.297                          2.678
# 11                            2.412                          2.774
# 12                            2.373                          2.872
# 13                            2.595                          3.029
# 14                            2.136                          2.612
# 15                            2.250                          2.827
# 16                            2.084                          2.686
# 17                            2.116                          2.639
# 18                            2.375                          3.100
# 19                            2.345                          2.891
# 20                            2.142                          2.590
# 21                            2.185                          2.910
# 22                            2.299                          3.040
# 23                            2.055                          2.874
# 24                            2.459                          3.015
# 25                            2.268                          2.437
# 26                            2.465                          2.990
# 27                            2.329                          2.987
# 28                            2.462                          2.880
# 29                            2.246                          2.840
# ...                             ...                            ...
# 1055                          1.964                          2.462
# 1056                          2.377                          2.571
# 1057                          2.016                          2.782
# 1058                          2.436                          3.029
# 1059                          2.283                          2.864
# 1060                          2.350                          2.818
# 1061                          2.404                          2.842
# 1062                          2.221                          2.919
# 1063                          2.313                          3.024
# 1064                          2.514                          3.077
# 1065                          2.083                          2.590
# 1066                          2.036                          2.741
# 1067                          2.131                          2.777
# 1068                          2.169                          2.859
# 1069                          2.406                          2.644
# 1070                          2.004                          2.643
# 1071                          2.502                          3.010
# 1072                          2.348                          2.804
# 1073                          2.159                          2.649
# 1074                          2.257                          2.870
# 1075                          2.355                          2.794
# 1076                          2.490                          2.990
# 1077                          2.272                          2.564
# 1078                          2.276                          2.694
# 1079                          1.989                          2.383
# 1080                          2.162                          2.468
# 1081                          2.039                          2.501
# 1082                          2.066                          2.761
# 1083                          1.956                          2.563
# 1084                          1.985                          2.756
#
#       lh_supramarginal_thickness  lh_frontalpole_thickness  \
# 0                          2.642                     3.043
# 1                          2.715                     2.763
# 2                          2.710                     2.676
# 3                          2.662                     2.880
# 4                          2.453                     2.736
# 5                          2.401                     2.364
# 6                          2.463                     2.861
# 7                          2.518                     2.531
# 8                          2.398                     2.916
# 9                          2.757                     3.062
# 10                         2.668                     3.055
# 11                         2.683                     2.656
# 12                         2.637                     2.659
# 13                         2.889                     3.032
# 14                         2.349                     2.908
# 15                         2.627                     2.720
# 16                         2.259                     2.484
# 17                         2.546                     2.491
# 18                         2.709                     3.270
# 19                         2.657                     2.764
# 20                         2.510                     2.882
# 21                         2.489                     2.785
# 22                         2.634                     3.277
# 23                         2.432                     2.650
# 24                         2.732                     3.210
# 25                         2.472                     3.285
# 26                         2.697                     3.051
# 27                         2.740                     3.507
# 28                         2.707                     3.311
# 29                         2.755                     2.926
# ...                          ...                       ...
# 1055                       2.398                     2.576
# 1056                       2.445                     3.084
# 1057                       2.308                     2.848
# 1058                       2.766                     3.056
# 1059                       2.457                     2.941
# 1060                       2.667                     3.025
# 1061                       2.708                     3.278
# 1062                       2.710                     2.763
# 1063                       2.648                     2.616
# 1064                       2.806                     3.326
# 1065                       2.399                     2.881
# 1066                       2.520                     2.657
# 1067                       2.299                     2.753
# 1068                       2.681                     2.595
# 1069                       2.558                     2.971
# 1070                       2.436                     2.387
# 1071                       2.803                     3.136
# 1072                       2.553                     2.557
# 1073                       2.469                     2.480
# 1074                       2.777                     2.987
# 1075                       2.646                     3.124
# 1076                       2.758                     3.146
# 1077                       2.692                     2.952
# 1078                       2.512                     2.804
# 1079                       2.261                     2.660
# 1080                       2.301                     2.857
# 1081                       2.425                     2.373
# 1082                       2.494                     2.788
# 1083                       2.238                     2.741
# 1084                       2.431                     2.399
#
#       lh_temporalpole_thickness  lh_transversetemporal_thickness  \
# 0                         3.662                            2.460
# 1                         3.699                            2.395
# 2                         4.050                            2.225
# 3                         3.712                            2.179
# 4                         3.646                            1.956
# 5                         3.690                            2.240
# 6                         3.733                            2.067
# 7                         4.114                            2.135
# 8                         3.453                            2.211
# 9                         3.770                            2.513
# 10                        4.078                            2.287
# 11                        3.890                            2.273
# 12                        3.781                            2.337
# 13                        4.025                            2.761
# 14                        3.468                            2.152
# 15                        3.696                            2.385
# 16                        3.667                            2.692
# 17                        3.433                            2.261
# 18                        3.394                            2.622
# 19                        3.832                            2.331
# 20                        3.514                            2.109
# 21                        3.725                            2.429
# 22                        3.589                            2.515
# 23                        3.844                            2.200
# 24                        3.610                            2.366
# 25                        3.801                            2.037
# 26                        3.818                            2.516
# 27                        3.559                            2.171
# 28                        3.790                            2.393
# 29                        3.887                            2.086
# ...                         ...                              ...
# 1055                      3.940                            1.738
# 1056                      3.481                            2.046
# 1057                      3.938                            2.440
# 1058                      4.000                            2.487
# 1059                      3.760                            2.357
# 1060                      3.182                            2.314
# 1061                      3.613                            2.477
# 1062                      3.580                            2.703
# 1063                      3.927                            2.641
# 1064                      3.722                            2.740
# 1065                      3.793                            2.053
# 1066                      3.926                            2.341
# 1067                      3.496                            2.057
# 1068                      3.626                            2.390
# 1069                      3.576                            2.258
# 1070                      3.586                            1.959
# 1071                      3.903                            2.510
# 1072                      3.944                            2.520
# 1073                      3.564                            2.105
# 1074                      4.087                            2.338
# 1075                      3.829                            2.417
# 1076                      3.457                            2.575
# 1077                      3.839                            1.745
# 1078                      3.861                            1.874
# 1079                      3.086                            2.082
# 1080                      3.066                            1.928
# 1081                      3.441                            2.077
# 1082                      3.511                            2.294
# 1083                      3.286                            1.779
# 1084                      3.708                            2.142
#
#       lh_insula_thickness lh_MeanThickness_thickness
# 0                   3.062                    2.63478
# 1                   3.242                    2.60656
# 2                   2.902                    2.57094
# 3                   2.566                    2.45492
# 4                   2.889                    2.36957
# 5                   3.110                    2.39852
# 6                   3.098                    2.48641
# 7                   3.052                    2.43681
# 8                   2.510                    2.42755
# 9                   3.013                    2.57659
# 10                  2.972                    2.55119
# 11                  2.861                    2.54070
# 12                  3.208                    2.61986
# 13                  3.520                    2.79868
# 14                  3.011                    2.36478
# 15                  3.036                    2.55071
# 16                  2.601                    2.40339
# 17                  2.910                    2.39204
# 18                  3.165                    2.66311
# 19                  2.879                    2.53995
# 20                  2.849                    2.43740
# 21                  2.889                    2.47180
# 22                  3.233                    2.68424
# 23                  2.835                    2.37603
# 24                  3.201                    2.69843
# 25                  2.905                    2.49231
# 26                  3.109                    2.66191
# 27                  3.146                    2.68472
# 28                  3.080                    2.59884
# 29                  2.983                    2.57240
# ...                   ...                        ...
# 1055                2.751                    2.34176
# 1056                2.757                    2.45031
# 1057                2.906                    2.37110
# 1058                3.198                    2.68459
# 1059                2.995                    2.55113
# 1060                2.973                    2.59911
# 1061                3.132                    2.72968
# 1062                3.086                    2.51336
# 1063                3.284                    2.61169
# 1064                2.893                    2.68700
# 1065                2.787                    2.36009
# 1066                3.052                    2.44325
# 1067                2.755                    2.35465
# 1068                3.066                    2.50683
# 1069                2.963                    2.47238
# 1070                2.752                    2.36568
# 1071                3.282                    2.68340
# 1072                2.939                    2.47506
# 1073                3.134                    2.45388
# 1074                3.062                    2.61704
# 1075                3.210                    2.60914
# 1076                3.026                    2.68455
# 1077                3.026                    2.51654
# 1078                2.648                    2.45838
# 1079                2.677                    2.24774
# 1080                2.742                    2.38182
# 1081                2.423                    2.28107
# 1082                2.928                    2.45424
# 1083                2.458                    2.20697
# 1084                2.925                    2.38137
#
# [1085 rows x 55 columns]

# %%
target
# Out:
# 'Age'

# %% [markdown]
# ### Discretization of Age variable
# Quantile-based discretization function. Discretize variable into equal-sized buckets based on rank or based on sample quantiles. For example 1000 values for 10 quantiles would produce a Categorical object indicating quantile membership for each data point.

# %%
pd.qcut(data['Age'], 8).head(1)
# Out:
# 0    (16.999, 20.0]
# Name: Age, dtype: category
# Categories (8, interval[float64]): [(16.999, 20.0] < (20.0, 21.0] < (21.0, 30.06] < (30.06, 44.0] < (44.0, 52.515] < (52.515, 58.0] < (58.0, 64.0] < (64.0, 83.458]]

# %% [markdown]
# #### Columns with missing values

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),4).sort_values(ascending=False))

# %%
missing(df_lh)
# Out:
# lh_MeanThickness_thickness               0.0
# Left-choroid-plexus                      0.0
# lh_entorhinal_thickness                  0.0
# lh_cuneus_thickness                      0.0
# lh_caudalmiddlefrontal_thickness         0.0
# lh_caudalanteriorcingulate_thickness     0.0
# lh_bankssts_thickness                    0.0
# lh.aparc.thickness                       0.0
# lhSurfaceHoles                           0.0
# lhCerebralWhiteMatterVol                 0.0
# lhCortexVol                              0.0
# Left-non-WM-hypointensities              0.0
# Left-WM-hypointensities                  0.0
# Left-vessel                              0.0
# lh_inferiorparietal_thickness            0.0
# Left-VentralDC                           0.0
# Left-Accumbens-area                      0.0
# Left-Amygdala                            0.0
# Left-Hippocampus                         0.0
# Left-Pallidum                            0.0
# Left-Putamen                             0.0
# Left-Caudate                             0.0
# Left-Thalamus-Proper                     0.0
# Left-Cerebellum-Cortex                   0.0
# Left-Cerebellum-White-Matter             0.0
# Left-Inf-Lat-Vent                        0.0
# lh_fusiform_thickness                    0.0
# lh_inferiortemporal_thickness            0.0
# lh_insula_thickness                      0.0
# lh_posteriorcingulate_thickness          0.0
# lh_transversetemporal_thickness          0.0
# lh_temporalpole_thickness                0.0
# lh_frontalpole_thickness                 0.0
# lh_supramarginal_thickness               0.0
# lh_superiortemporal_thickness            0.0
# lh_superiorparietal_thickness            0.0
# lh_superiorfrontal_thickness             0.0
# lh_rostralmiddlefrontal_thickness        0.0
# lh_rostralanteriorcingulate_thickness    0.0
# lh_precuneus_thickness                   0.0
# lh_precentral_thickness                  0.0
# lh_postcentral_thickness                 0.0
# lh_isthmuscingulate_thickness            0.0
# lh_pericalcarine_thickness               0.0
# lh_parstriangularis_thickness            0.0
# lh_parsorbitalis_thickness               0.0
# lh_parsopercularis_thickness             0.0
# lh_paracentral_thickness                 0.0
# lh_parahippocampal_thickness             0.0
# lh_middletemporal_thickness              0.0
# lh_medialorbitofrontal_thickness         0.0
# lh_lingual_thickness                     0.0
# lh_lateralorbitofrontal_thickness        0.0
# lh_lateraloccipital_thickness            0.0
# Left-Lateral-Ventricle                   0.0
# dtype: float64

# %% [markdown]
# #### How to remove columns with too many missing values in Python
# https://stackoverflow.com/questions/45515031/how-to-remove-columns-with-too-many-missing-values-in-python

# %%
def rmissingvaluecol(dff,threshold):
    l = []
    l = list(dff.drop(dff.loc[:,list((100*(dff.isnull().sum()/len(dff.index))>=threshold))].columns, 1).columns.values)
    print("# Columns having more than %s percent missing values:"%threshold,(dff.shape[1] - len(l)))
    print("Columns:\n",list(set(list((dff.columns.values))) - set(l)))
    return l

# %%
#Here threshold is 10% which means we are going to drop columns having more than 10% of missing values
rmissingvaluecol(data,10)
# Out:
# # Columns having more than 10 percent missing values: 4
# Columns:
#  ['Height', 'FieldStrength', 'Weight', 'Handedness']
# ['SubjectID',
#  'Source',
#  'ID',
#  'Sex',
#  'Measure:volume',
#  'Left-Lateral-Ventricle',
#  'Left-Inf-Lat-Vent',
#  'Left-Cerebellum-White-Matter',
#  'Left-Cerebellum-Cortex',
#  'Left-Thalamus-Proper',
#  'Left-Caudate',
#  'Left-Putamen',
#  'Left-Pallidum',
#  '3rd-Ventricle',
#  '4th-Ventricle',
#  'Brain-Stem',
#  'Left-Hippocampus',
#  'Left-Amygdala',
#  'CSF',
#  'Left-Accumbens-area',
#  'Left-VentralDC',
#  'Left-vessel',
#  'Left-choroid-plexus',
#  'Right-Lateral-Ventricle',
#  'Right-Inf-Lat-Vent',
#  'Right-Cerebellum-White-Matter',
#  'Right-Cerebellum-Cortex',
#  'Right-Thalamus-Proper',
#  'Right-Caudate',
#  'Right-Putamen',
#  'Right-Pallidum',
#  'Right-Hippocampus',
#  'Right-Amygdala',
#  'Right-Accumbens-area',
#  'Right-VentralDC',
#  'Right-vessel',
#  'Right-choroid-plexus',
#  '5th-Ventricle',
#  'WM-hypointensities',
#  'Left-WM-hypointensities',
#  'Right-WM-hypointensities',
#  'non-WM-hypointensities',
#  'Left-non-WM-hypointensities',
#  'Right-non-WM-hypointensities',
#  'Optic-Chiasm',
#  'CC_Posterior',
#  'CC_Mid_Posterior',
#  'CC_Central',
#  'CC_Mid_Anterior',
#  'CC_Anterior',
#  'BrainSegVol',
#  'BrainSegVolNotVent_x',
#  'BrainSegVolNotVentSurf',
#  'lhCortexVol',
#  'rhCortexVol',
#  'CortexVol',
#  'lhCerebralWhiteMatterVol',
#  'rhCerebralWhiteMatterVol',
#  'CerebralWhiteMatterVol',
#  'SubCortGrayVol',
#  'TotalGrayVol',
#  'SupraTentorialVol',
#  'SupraTentorialVolNotVent',
#  'SupraTentorialVolNotVentVox',
#  'MaskVol',
#  'BrainSegVol-to-eTIV',
#  'MaskVol-to-eTIV',
#  'lhSurfaceHoles',
#  'rhSurfaceHoles',
#  'SurfaceHoles',
#  'EstimatedTotalIntraCranialVol',
#  'lh.aparc.thickness',
#  'lh_bankssts_thickness',
#  'lh_caudalanteriorcingulate_thickness',
#  'lh_caudalmiddlefrontal_thickness',
#  'lh_cuneus_thickness',
#  'lh_entorhinal_thickness',
#  'lh_fusiform_thickness',
#  'lh_inferiorparietal_thickness',
#  'lh_inferiortemporal_thickness',
#  'lh_isthmuscingulate_thickness',
#  'lh_lateraloccipital_thickness',
#  'lh_lateralorbitofrontal_thickness',
#  'lh_lingual_thickness',
#  'lh_medialorbitofrontal_thickness',
#  'lh_middletemporal_thickness',
#  'lh_parahippocampal_thickness',
#  'lh_paracentral_thickness',
#  'lh_parsopercularis_thickness',
#  'lh_parsorbitalis_thickness',
#  'lh_parstriangularis_thickness',
#  'lh_pericalcarine_thickness',
#  'lh_postcentral_thickness',
#  'lh_posteriorcingulate_thickness',
#  'lh_precentral_thickness',
#  'lh_precuneus_thickness',
#  'lh_rostralanteriorcingulate_thickness',
#  'lh_rostralmiddlefrontal_thickness',
#  'lh_superiorfrontal_thickness',
#  'lh_superiorparietal_thickness',
#  'lh_superiortemporal_thickness',
#  'lh_supramarginal_thickness',
#  'lh_frontalpole_thickness',
#  'lh_temporalpole_thickness',
#  'lh_transversetemporal_thickness',
#  'lh_insula_thickness',
#  'lh_MeanThickness_thickness',
#  'BrainSegVolNotVent_y',
#  'eTIV_x',
#  'rh.aparc.thickness',
#  'rh_bankssts_thickness',
#  'rh_caudalanteriorcingulate_thickness',
#  'rh_caudalmiddlefrontal_thickness',
#  'rh_cuneus_thickness',
#  'rh_entorhinal_thickness',
#  'rh_fusiform_thickness',
#  'rh_inferiorparietal_thickness',
#  'rh_inferiortemporal_thickness',
#  'rh_isthmuscingulate_thickness',
#  'rh_lateraloccipital_thickness',
#  'rh_lateralorbitofrontal_thickness',
#  'rh_lingual_thickness',
#  'rh_medialorbitofrontal_thickness',
#  'rh_middletemporal_thickness',
#  'rh_parahippocampal_thickness',
#  'rh_paracentral_thickness',
#  'rh_parsopercularis_thickness',
#  'rh_parsorbitalis_thickness',
#  'rh_parstriangularis_thickness',
#  'rh_pericalcarine_thickness',
#  'rh_postcentral_thickness',
#  'rh_posteriorcingulate_thickness',
#  'rh_precentral_thickness',
#  'rh_precuneus_thickness',
#  'rh_rostralanteriorcingulate_thickness',
#  'rh_rostralmiddlefrontal_thickness',
#  'rh_superiorfrontal_thickness',
#  'rh_superiorparietal_thickness',
#  'rh_superiortemporal_thickness',
#  'rh_supramarginal_thickness',
#  'rh_frontalpole_thickness',
#  'rh_temporalpole_thickness',
#  'rh_transversetemporal_thickness',
#  'rh_insula_thickness',
#  'rh_MeanThickness_thickness',
#  'BrainSegVolNotVent',
#  'eTIV_y',
#  'Age']

# %%
# Now create new dataframe excluding these columns
l = rmissingvaluecol(data,10)
data1 = data[l]
# Out:
# # Columns having more than 10 percent missing values: 4
# Columns:
#  ['Height', 'FieldStrength', 'Weight', 'Handedness']

# %%
# missing(data[features])

# %% [markdown]
# #### Correlations between features and target

# %%
correlations = {}
for f in features:
    data_temp = data1[[f,target]]
    x1 = data_temp[f].values
    x2 = data_temp[target].values
    key = f + ' vs ' + target
    correlations[key] = pearsonr(x1,x2)[0]

# %%
data_correlations = pd.DataFrame(correlations, index=['Value']).T
data_correlations.loc[data_correlations['Value'].abs().sort_values(ascending=False).index]
# Out:
#                                         Value
# lh_insula_thickness vs Age          -0.572424
# rh_insula_thickness vs Age          -0.547666
# rh_parsorbitalis_thickness vs Age   -0.501914
# lh_parsorbitalis_thickness vs Age   -0.464792
# Left-Lateral-Ventricle vs Age        0.458784
# Right-Lateral-Ventricle vs Age       0.446086
# rh_parahippocampal_thickness vs Age -0.214836
# lh_parahippocampal_thickness vs Age -0.173509

# %% [markdown]
# #### We can see that the top 5 features are the most correlated features with the target "Age"

# %%
y = data.loc[:,['lh_insula_thickness','rh_insula_thickness',target]].sort_values(target, ascending=True).values
x = np.arange(y.shape[0])

# %%
# %matplotlib inline
plt.subplot(3,1,1)
plt.plot(x,y[:,0])
plt.title('lh_insula_thickness and rh_insula_thickness vs Age')
plt.ylabel('lh_insula_thickness')

plt.subplot(3,1,2)
plt.plot(x,y[:,1])
plt.ylabel('rh_insula_thickness')

plt.subplot(3,1,3)
plt.plot(x,y[:,2],'r')
plt.ylabel("Age")

plt.show()

# %% [markdown]
# ### Predicting Age

# %%
# Train a simple linear regression model
regr = linear_model.LinearRegression()
new_data = data[features]

# %%
X = new_data.values
y = data.Age.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2)

# %%
regr.fit(X_train, y_train)
print(regr.predict(X_test))
# Out:
# [ 40.26215822  52.73759521  32.38092553  69.94745346  40.74674538
#   42.81256113  26.33642016  18.99090684  40.61615371  51.19628677
#   45.97370323  44.36776157  19.84677273  56.20778796  63.02045595
#   25.38893895  52.34309984  45.74582733  22.62640226  45.14721014
#   37.14349031  28.32441254  24.10945518  29.30161616  37.93751988
#   28.23567073  34.7513464   31.39147949  36.13830631  58.25515543
#   35.57164764  45.69784681  45.15737594  30.06739509  34.12306674
#   51.66018966  47.71524995  58.81758066  55.65393097  52.51658456
#   44.18512012  30.79376463  32.22232595  38.51828841  52.96832978
#   46.92018209  46.12072676  25.46805051  47.12062023  39.03335715
#   30.05147109  38.79004408  35.03470988  43.46331263  36.32689369
#   48.90200731  31.73084835  29.29195648 114.73773053  38.24888887
#   26.11832624  34.7462788   25.45241279  74.5893491   32.78911877
#   24.48251944  56.45219477  36.12498349  75.3288535   44.41877628
#   37.98615202  43.54654305  40.85339155  52.58007581  78.77423028
#   29.59495972  45.51088251  56.57490001  38.16899527  34.71658266
#   76.8004311   49.50590078  57.09155261  21.65712491  51.11620288
#   29.80038204  36.78985014  22.84257521  39.92421952  36.03288869
#   45.10387113  24.56428404  48.22150475  51.59263692  43.02033523
#   37.05562024  62.60980768  42.28242175  30.79547489  32.60328903
#   29.38755278  37.75884994  42.40022526  29.90475668  49.42087884
#   48.94888693  31.68679825  35.80977306  29.96837714  60.10826179
#   43.27746634  57.8122699   25.06753277  53.7659823   51.97374535
#   51.06587471  35.83987448  42.37056988  30.42440856  46.4567182
#   36.32989379  34.75805316  35.76178737  48.52690606  44.68705588
#   33.84440278  30.23105584  20.36428273  36.30820155  40.67482003
#   47.98653361  40.18712535  30.66578171  45.26595262  23.70375143
#   25.82974016  43.25642709  24.66856209  40.55382014  38.38516975
#   38.57785346  35.80171053  57.85234136  52.10071293  57.88729102
#   36.83679636  19.51881443  39.27125599  19.8174166   33.34619031
#   42.97007128  31.93794503  38.84718547  31.06509786  33.28890478
#   21.06786699  41.74040308  50.10704901  30.90925312  58.28471697
#   47.61880804  38.78760754  51.48352856  88.70077411  48.46445436
#   38.48157829  37.14272731  60.54347078  38.30903265  42.77007237
#   29.47713791  59.14186855  40.73437395  49.39758207  27.54173722
#   49.05241739  66.21363573  36.3753923   50.27229993  55.93518674
#   50.35393379  60.01225016  58.7745546   48.8329128   53.66858163
#   56.60071593  39.56540148  59.57448537  48.46650818  52.06455537
#   70.66170007  37.73805216  34.18627196  33.66912982  46.36351148
#   33.31082487  38.55948214  33.04736139  31.38092771  35.20967449
#   34.8712002   34.6485859   24.41518528  46.25768592  39.18291793
#   29.80731816  27.92804469  36.89325516  44.84580703  44.2700266
#   31.97058615  55.18676331  53.69868612  41.76695067  43.01728287
#   46.10134902  29.29131122]

# %%
regr.score(X_test,y_test)
# Out:
# 0.4750674148517645

# %%
# Calculate the Root Mean Squared Error
print("RMSE: %.2f"
      % math.sqrt(np.mean((regr.predict(X_test) - y_test) ** 2)))
# Out:
# RMSE: 12.77

# %%
# Let's try XGboost algorithm to see if we can get better results
xgb = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7)

# %%
traindf, testdf = train_test_split(X_train, test_size = 0.3)
xgb.fit(X_train,y_train)
# Out:
# [22:23:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.08, max_delta_step=0,
#        max_depth=7, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.75, verbosity=1)

# %%
predictions = xgb.predict(X_test)
print(explained_variance_score(predictions,y_test))
# Out:
# 0.32469110931920553

# %% [markdown]
# ### This is worse than a simple regression model

# %% [markdown]
# We can use `.describe()` to calculate simple **descriptive statistics** for the dataset (rounding to 3 decimals):

# %%
new_data.describe().round(3).T
# Out:
#                                count      mean       std       min       25%  \
# lh_parsorbitalis_thickness    1085.0     2.762     0.214     1.599     2.629
# rh_parsorbitalis_thickness    1085.0     2.771     0.214     1.745     2.632
# lh_parahippocampal_thickness  1085.0     2.735     0.298     1.589     2.543
# rh_parahippocampal_thickness  1085.0     2.700     0.248     1.780     2.538
# Left-Lateral-Ventricle        1085.0  8635.934  5515.628  2284.700  5113.900
# Right-Lateral-Ventricle       1085.0  7851.851  5212.003  2222.600  4639.000
# lh_insula_thickness           1085.0     2.972     0.194     1.498     2.869
# rh_insula_thickness           1085.0     2.988     0.197     1.486     2.871
#
#                                    50%        75%        max
# lh_parsorbitalis_thickness       2.762      2.905      3.462
# rh_parsorbitalis_thickness       2.775      2.914      3.505
# lh_parahippocampal_thickness     2.737      2.937      3.709
# rh_parahippocampal_thickness     2.711      2.859      3.471
# Left-Lateral-Ventricle        7219.100  10394.900  56121.400
# Right-Lateral-Ventricle       6403.600   9455.400  56343.400
# lh_insula_thickness              2.979      3.102      3.546
# rh_insula_thickness              2.996      3.125      3.586

# %% [markdown]
# Computing the **pairwise correlation of columns** (features). Method could be ‘pearson’ (default), ‘kendall’, or ‘spearman’.

# %%
new_data.corr().round(2)
# Out:
#                               lh_parsorbitalis_thickness  \
# lh_parsorbitalis_thickness                          1.00
# rh_parsorbitalis_thickness                          0.59
# lh_parahippocampal_thickness                        0.20
# rh_parahippocampal_thickness                        0.26
# Left-Lateral-Ventricle                             -0.27
# Right-Lateral-Ventricle                            -0.29
# lh_insula_thickness                                 0.50
# rh_insula_thickness                                 0.48
#
#                               rh_parsorbitalis_thickness  \
# lh_parsorbitalis_thickness                          0.59
# rh_parsorbitalis_thickness                          1.00
# lh_parahippocampal_thickness                        0.22
# rh_parahippocampal_thickness                        0.29
# Left-Lateral-Ventricle                             -0.26
# Right-Lateral-Ventricle                            -0.27
# lh_insula_thickness                                 0.52
# rh_insula_thickness                                 0.52
#
#                               lh_parahippocampal_thickness  \
# lh_parsorbitalis_thickness                            0.20
# rh_parsorbitalis_thickness                            0.22
# lh_parahippocampal_thickness                          1.00
# rh_parahippocampal_thickness                          0.70
# Left-Lateral-Ventricle                               -0.29
# Right-Lateral-Ventricle                              -0.25
# lh_insula_thickness                                   0.26
# rh_insula_thickness                                   0.25
#
#                               rh_parahippocampal_thickness  \
# lh_parsorbitalis_thickness                            0.26
# rh_parsorbitalis_thickness                            0.29
# lh_parahippocampal_thickness                          0.70
# rh_parahippocampal_thickness                          1.00
# Left-Lateral-Ventricle                               -0.27
# Right-Lateral-Ventricle                              -0.29
# lh_insula_thickness                                   0.31
# rh_insula_thickness                                   0.33
#
#                               Left-Lateral-Ventricle  Right-Lateral-Ventricle  \
# lh_parsorbitalis_thickness                     -0.27                    -0.29
# rh_parsorbitalis_thickness                     -0.26                    -0.27
# lh_parahippocampal_thickness                   -0.29                    -0.25
# rh_parahippocampal_thickness                   -0.27                    -0.29
# Left-Lateral-Ventricle                          1.00                     0.92
# Right-Lateral-Ventricle                         0.92                     1.00
# lh_insula_thickness                            -0.32                    -0.32
# rh_insula_thickness                            -0.37                    -0.36
#
#                               lh_insula_thickness  rh_insula_thickness
# lh_parsorbitalis_thickness                   0.50                 0.48
# rh_parsorbitalis_thickness                   0.52                 0.52
# lh_parahippocampal_thickness                 0.26                 0.25
# rh_parahippocampal_thickness                 0.31                 0.33
# Left-Lateral-Ventricle                      -0.32                -0.37
# Right-Lateral-Ventricle                     -0.32                -0.36
# lh_insula_thickness                          1.00                 0.73
# rh_insula_thickness                          0.73                 1.00

# %%
new_data.describe()
# Out:
#        lh_parsorbitalis_thickness  rh_parsorbitalis_thickness  \
# count                 1085.000000                 1085.000000
# mean                     2.762101                    2.770634
# std                      0.214068                    0.213805
# min                      1.599000                    1.745000
# 25%                      2.629000                    2.632000
# 50%                      2.762000                    2.775000
# 75%                      2.905000                    2.914000
# max                      3.462000                    3.505000
#
#        lh_parahippocampal_thickness  rh_parahippocampal_thickness  \
# count                   1085.000000                   1085.000000
# mean                       2.735071                      2.699907
# std                        0.298453                      0.248156
# min                        1.589000                      1.780000
# 25%                        2.543000                      2.538000
# 50%                        2.737000                      2.711000
# 75%                        2.937000                      2.859000
# max                        3.709000                      3.471000
#
#        Left-Lateral-Ventricle  Right-Lateral-Ventricle  lh_insula_thickness  \
# count             1085.000000              1085.000000          1085.000000
# mean              8635.933733              7851.850507             2.972150
# std               5515.628037              5212.003164             0.194034
# min               2284.700000              2222.600000             1.498000
# 25%               5113.900000              4639.000000             2.869000
# 50%               7219.100000              6403.600000             2.979000
# 75%              10394.900000              9455.400000             3.102000
# max              56121.400000             56343.400000             3.546000
#
#        rh_insula_thickness
# count          1085.000000
# mean              2.988305
# std               0.197194
# min               1.486000
# 25%               2.871000
# 50%               2.996000
# 75%               3.125000
# max               3.586000

# %% [markdown]
# Splitting the object (iris DataFrame) **into groups** (species)

# %%
grouped = data.groupby('Sex')

# %%
grouped.groups
# Out:
# {'F': Int64Index([   0,    1,    2,    7,    8,   13,   16,   17,   19,   20,
#              ...
#              1073, 1075, 1076, 1078, 1079, 1080, 1081, 1082, 1083, 1084],
#             dtype='int64', length=611),
#  'M': Int64Index([   3,    4,    5,    6,    9,   10,   11,   12,   14,   15,
#              ...
#              1052, 1053, 1054, 1060, 1061, 1066, 1067, 1071, 1074, 1077],
#             dtype='int64', length=474)}

# %% [markdown]
# Describe the group-wise `PetalLength` summary statistics

# %%
print('Age:')
grouped['Age'].describe()
# Out:
# Age:
#      count       mean        std   min   25%        50%   75%        max
# Sex
# F    611.0  42.937321  18.917609  17.0  21.0  46.006845  59.0  81.941136
# M    474.0  41.099283  18.111956  17.0  21.0  41.000000  56.0  83.457906

# %% [markdown]
# Iterating through the grouped data is very natural

# %%
for name, group in grouped:
    print(name,':')
    print(group.describe().round(2).head(3))
# Out:
# F :
#        SubjectID  Height  Weight  Handedness  Measure:volume  \
# count     611.00  202.00  202.00       81.00           611.0
# mean      764.03  163.23   65.93       94.94             0.0
# std       450.63    7.77   16.09       15.50             0.0
#
#        Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# count                  611.00             611.00
# mean                  7897.59             289.78
# std                   5118.12             191.02
#
#        Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# count                        611.00                  611.00
# mean                       14641.69                51303.14
# std                         2275.35                 5657.52
#
#        Left-Thalamus-Proper  ...  rh_superiortemporal_thickness  \
# count                611.00  ...                         611.00
# mean                7344.60  ...                           2.81
# std                  895.28  ...                           0.20
#
#        rh_supramarginal_thickness  rh_frontalpole_thickness  \
# count                      611.00                    611.00
# mean                         2.56                      2.83
# std                          0.17                      0.28
#
#        rh_temporalpole_thickness  rh_transversetemporal_thickness  \
# count                     611.00                           611.00
# mean                        3.75                             2.34
# std                         0.30                             0.26
#
#        rh_insula_thickness  rh_MeanThickness_thickness  BrainSegVolNotVent  \
# count               611.00                      611.00              611.00
# mean                  2.97                        2.51          1072761.22
# std                   0.20                        0.14            96248.66
#
#            eTIV_y     Age
# count      611.00  611.00
# mean   1425366.41   42.94
# std     126535.10   18.92
#
# [3 rows x 146 columns]
# M :
#        SubjectID  Height  Weight  Handedness  Measure:volume  \
# count     474.00  181.00  181.00       31.00           474.0
# mean      781.12  176.94   78.63       92.69             0.0
# std       444.63    7.98   17.00       26.44             0.0
#
#        Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# count                  474.00             474.00
# mean                  9587.68             347.96
# std                   5858.83             220.57
#
#        Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  \
# count                        474.00                  474.00
# mean                       15906.66                57497.89
# std                         2703.39                 6289.00
#
#        Left-Thalamus-Proper  ...  rh_superiortemporal_thickness  \
# count                474.00  ...                         474.00
# mean                8141.47  ...                           2.84
# std                  971.97  ...                           0.18
#
#        rh_supramarginal_thickness  rh_frontalpole_thickness  \
# count                      474.00                    474.00
# mean                         2.57                      2.79
# std                          0.16                      0.29
#
#        rh_temporalpole_thickness  rh_transversetemporal_thickness  \
# count                     474.00                           474.00
# mean                        3.77                             2.37
# std                         0.29                             0.23
#
#        rh_insula_thickness  rh_MeanThickness_thickness  BrainSegVolNotVent  \
# count               474.00                      474.00              474.00
# mean                  3.02                        2.52          1207838.10
# std                   0.19                        0.13           110806.96
#
#            eTIV_y     Age
# count      474.00  474.00
# mean   1631575.33   41.10
# std     135881.80   18.11
#
# [3 rows x 146 columns]

# %% [markdown]
# **Group-wise feature correlations**

# %%
data.groupby('Age').corr().round(3)
# Out:
#                                                  SubjectID  Height  Weight  \
# Age
# 17.000000 SubjectID                                    1.0     NaN     NaN
#           Height                                       NaN     NaN     NaN
#           Weight                                       NaN     NaN     NaN
#           Handedness                                   NaN     NaN     NaN
#           Measure:volume                               NaN     NaN     NaN
#           Left-Lateral-Ventricle                      -1.0     NaN     NaN
#           Left-Inf-Lat-Vent                           -1.0     NaN     NaN
#           Left-Cerebellum-White-Matter                 1.0     NaN     NaN
#           Left-Cerebellum-Cortex                       1.0     NaN     NaN
#           Left-Thalamus-Proper                        -1.0     NaN     NaN
#           Left-Caudate                                -1.0     NaN     NaN
#           Left-Putamen                                -1.0     NaN     NaN
#           Left-Pallidum                               -1.0     NaN     NaN
#           3rd-Ventricle                               -1.0     NaN     NaN
#           4th-Ventricle                               -1.0     NaN     NaN
#           Brain-Stem                                  -1.0     NaN     NaN
#           Left-Hippocampus                             1.0     NaN     NaN
#           Left-Amygdala                               -1.0     NaN     NaN
#           CSF                                          1.0     NaN     NaN
#           Left-Accumbens-area                         -1.0     NaN     NaN
#           Left-VentralDC                              -1.0     NaN     NaN
#           Left-vessel                                 -1.0     NaN     NaN
#           Left-choroid-plexus                          1.0     NaN     NaN
#           Right-Lateral-Ventricle                     -1.0     NaN     NaN
#           Right-Inf-Lat-Vent                           1.0     NaN     NaN
#           Right-Cerebellum-White-Matter                1.0     NaN     NaN
#           Right-Cerebellum-Cortex                      1.0     NaN     NaN
#           Right-Thalamus-Proper                       -1.0     NaN     NaN
#           Right-Caudate                               -1.0     NaN     NaN
#           Right-Putamen                               -1.0     NaN     NaN
# ...                                                    ...     ...     ...
# 83.457906 rh_inferiortemporal_thickness                NaN     NaN     NaN
#           rh_isthmuscingulate_thickness                NaN     NaN     NaN
#           rh_lateraloccipital_thickness                NaN     NaN     NaN
#           rh_lateralorbitofrontal_thickness            NaN     NaN     NaN
#           rh_lingual_thickness                         NaN     NaN     NaN
#           rh_medialorbitofrontal_thickness             NaN     NaN     NaN
#           rh_middletemporal_thickness                  NaN     NaN     NaN
#           rh_parahippocampal_thickness                 NaN     NaN     NaN
#           rh_paracentral_thickness                     NaN     NaN     NaN
#           rh_parsopercularis_thickness                 NaN     NaN     NaN
#           rh_parsorbitalis_thickness                   NaN     NaN     NaN
#           rh_parstriangularis_thickness                NaN     NaN     NaN
#           rh_pericalcarine_thickness                   NaN     NaN     NaN
#           rh_postcentral_thickness                     NaN     NaN     NaN
#           rh_posteriorcingulate_thickness              NaN     NaN     NaN
#           rh_precentral_thickness                      NaN     NaN     NaN
#           rh_precuneus_thickness                       NaN     NaN     NaN
#           rh_rostralanteriorcingulate_thickness        NaN     NaN     NaN
#           rh_rostralmiddlefrontal_thickness            NaN     NaN     NaN
#           rh_superiorfrontal_thickness                 NaN     NaN     NaN
#           rh_superiorparietal_thickness                NaN     NaN     NaN
#           rh_superiortemporal_thickness                NaN     NaN     NaN
#           rh_supramarginal_thickness                   NaN     NaN     NaN
#           rh_frontalpole_thickness                     NaN     NaN     NaN
#           rh_temporalpole_thickness                    NaN     NaN     NaN
#           rh_transversetemporal_thickness              NaN     NaN     NaN
#           rh_insula_thickness                          NaN     NaN     NaN
#           rh_MeanThickness_thickness                   NaN     NaN     NaN
#           BrainSegVolNotVent                           NaN     NaN     NaN
#           eTIV_y                                       NaN     NaN     NaN
#
#                                                  Handedness  Measure:volume  \
# Age
# 17.000000 SubjectID                                     NaN             NaN
#           Height                                        NaN             NaN
#           Weight                                        NaN             NaN
#           Handedness                                    NaN             NaN
#           Measure:volume                                NaN             NaN
#           Left-Lateral-Ventricle                        NaN             NaN
#           Left-Inf-Lat-Vent                             NaN             NaN
#           Left-Cerebellum-White-Matter                  NaN             NaN
#           Left-Cerebellum-Cortex                        NaN             NaN
#           Left-Thalamus-Proper                          NaN             NaN
#           Left-Caudate                                  NaN             NaN
#           Left-Putamen                                  NaN             NaN
#           Left-Pallidum                                 NaN             NaN
#           3rd-Ventricle                                 NaN             NaN
#           4th-Ventricle                                 NaN             NaN
#           Brain-Stem                                    NaN             NaN
#           Left-Hippocampus                              NaN             NaN
#           Left-Amygdala                                 NaN             NaN
#           CSF                                           NaN             NaN
#           Left-Accumbens-area                           NaN             NaN
#           Left-VentralDC                                NaN             NaN
#           Left-vessel                                   NaN             NaN
#           Left-choroid-plexus                           NaN             NaN
#           Right-Lateral-Ventricle                       NaN             NaN
#           Right-Inf-Lat-Vent                            NaN             NaN
#           Right-Cerebellum-White-Matter                 NaN             NaN
#           Right-Cerebellum-Cortex                       NaN             NaN
#           Right-Thalamus-Proper                         NaN             NaN
#           Right-Caudate                                 NaN             NaN
#           Right-Putamen                                 NaN             NaN
# ...                                                     ...             ...
# 83.457906 rh_inferiortemporal_thickness                 NaN             NaN
#           rh_isthmuscingulate_thickness                 NaN             NaN
#           rh_lateraloccipital_thickness                 NaN             NaN
#           rh_lateralorbitofrontal_thickness             NaN             NaN
#           rh_lingual_thickness                          NaN             NaN
#           rh_medialorbitofrontal_thickness              NaN             NaN
#           rh_middletemporal_thickness                   NaN             NaN
#           rh_parahippocampal_thickness                  NaN             NaN
#           rh_paracentral_thickness                      NaN             NaN
#           rh_parsopercularis_thickness                  NaN             NaN
#           rh_parsorbitalis_thickness                    NaN             NaN
#           rh_parstriangularis_thickness                 NaN             NaN
#           rh_pericalcarine_thickness                    NaN             NaN
#           rh_postcentral_thickness                      NaN             NaN
#           rh_posteriorcingulate_thickness               NaN             NaN
#           rh_precentral_thickness                       NaN             NaN
#           rh_precuneus_thickness                        NaN             NaN
#           rh_rostralanteriorcingulate_thickness         NaN             NaN
#           rh_rostralmiddlefrontal_thickness             NaN             NaN
#           rh_superiorfrontal_thickness                  NaN             NaN
#           rh_superiorparietal_thickness                 NaN             NaN
#           rh_superiortemporal_thickness                 NaN             NaN
#           rh_supramarginal_thickness                    NaN             NaN
#           rh_frontalpole_thickness                      NaN             NaN
#           rh_temporalpole_thickness                     NaN             NaN
#           rh_transversetemporal_thickness               NaN             NaN
#           rh_insula_thickness                           NaN             NaN
#           rh_MeanThickness_thickness                    NaN             NaN
#           BrainSegVolNotVent                            NaN             NaN
#           eTIV_y                                        NaN             NaN
#
#                                                  Left-Lateral-Ventricle  \
# Age
# 17.000000 SubjectID                                                -1.0
#           Height                                                    NaN
#           Weight                                                    NaN
#           Handedness                                                NaN
#           Measure:volume                                            NaN
#           Left-Lateral-Ventricle                                    1.0
#           Left-Inf-Lat-Vent                                         1.0
#           Left-Cerebellum-White-Matter                             -1.0
#           Left-Cerebellum-Cortex                                   -1.0
#           Left-Thalamus-Proper                                      1.0
#           Left-Caudate                                              1.0
#           Left-Putamen                                              1.0
#           Left-Pallidum                                             1.0
#           3rd-Ventricle                                             1.0
#           4th-Ventricle                                             1.0
#           Brain-Stem                                                1.0
#           Left-Hippocampus                                         -1.0
#           Left-Amygdala                                             1.0
#           CSF                                                      -1.0
#           Left-Accumbens-area                                       1.0
#           Left-VentralDC                                            1.0
#           Left-vessel                                               1.0
#           Left-choroid-plexus                                      -1.0
#           Right-Lateral-Ventricle                                   1.0
#           Right-Inf-Lat-Vent                                       -1.0
#           Right-Cerebellum-White-Matter                            -1.0
#           Right-Cerebellum-Cortex                                  -1.0
#           Right-Thalamus-Proper                                     1.0
#           Right-Caudate                                             1.0
#           Right-Putamen                                             1.0
# ...                                                                 ...
# 83.457906 rh_inferiortemporal_thickness                             NaN
#           rh_isthmuscingulate_thickness                             NaN
#           rh_lateraloccipital_thickness                             NaN
#           rh_lateralorbitofrontal_thickness                         NaN
#           rh_lingual_thickness                                      NaN
#           rh_medialorbitofrontal_thickness                          NaN
#           rh_middletemporal_thickness                               NaN
#           rh_parahippocampal_thickness                              NaN
#           rh_paracentral_thickness                                  NaN
#           rh_parsopercularis_thickness                              NaN
#           rh_parsorbitalis_thickness                                NaN
#           rh_parstriangularis_thickness                             NaN
#           rh_pericalcarine_thickness                                NaN
#           rh_postcentral_thickness                                  NaN
#           rh_posteriorcingulate_thickness                           NaN
#           rh_precentral_thickness                                   NaN
#           rh_precuneus_thickness                                    NaN
#           rh_rostralanteriorcingulate_thickness                     NaN
#           rh_rostralmiddlefrontal_thickness                         NaN
#           rh_superiorfrontal_thickness                              NaN
#           rh_superiorparietal_thickness                             NaN
#           rh_superiortemporal_thickness                             NaN
#           rh_supramarginal_thickness                                NaN
#           rh_frontalpole_thickness                                  NaN
#           rh_temporalpole_thickness                                 NaN
#           rh_transversetemporal_thickness                           NaN
#           rh_insula_thickness                                       NaN
#           rh_MeanThickness_thickness                                NaN
#           BrainSegVolNotVent                                        NaN
#           eTIV_y                                                    NaN
#
#                                                  Left-Inf-Lat-Vent  \
# Age
# 17.000000 SubjectID                                           -1.0
#           Height                                               NaN
#           Weight                                               NaN
#           Handedness                                           NaN
#           Measure:volume                                       NaN
#           Left-Lateral-Ventricle                               1.0
#           Left-Inf-Lat-Vent                                    1.0
#           Left-Cerebellum-White-Matter                        -1.0
#           Left-Cerebellum-Cortex                              -1.0
#           Left-Thalamus-Proper                                 1.0
#           Left-Caudate                                         1.0
#           Left-Putamen                                         1.0
#           Left-Pallidum                                        1.0
#           3rd-Ventricle                                        1.0
#           4th-Ventricle                                        1.0
#           Brain-Stem                                           1.0
#           Left-Hippocampus                                    -1.0
#           Left-Amygdala                                        1.0
#           CSF                                                 -1.0
#           Left-Accumbens-area                                  1.0
#           Left-VentralDC                                       1.0
#           Left-vessel                                          1.0
#           Left-choroid-plexus                                 -1.0
#           Right-Lateral-Ventricle                              1.0
#           Right-Inf-Lat-Vent                                  -1.0
#           Right-Cerebellum-White-Matter                       -1.0
#           Right-Cerebellum-Cortex                             -1.0
#           Right-Thalamus-Proper                                1.0
#           Right-Caudate                                        1.0
#           Right-Putamen                                        1.0
# ...                                                            ...
# 83.457906 rh_inferiortemporal_thickness                        NaN
#           rh_isthmuscingulate_thickness                        NaN
#           rh_lateraloccipital_thickness                        NaN
#           rh_lateralorbitofrontal_thickness                    NaN
#           rh_lingual_thickness                                 NaN
#           rh_medialorbitofrontal_thickness                     NaN
#           rh_middletemporal_thickness                          NaN
#           rh_parahippocampal_thickness                         NaN
#           rh_paracentral_thickness                             NaN
#           rh_parsopercularis_thickness                         NaN
#           rh_parsorbitalis_thickness                           NaN
#           rh_parstriangularis_thickness                        NaN
#           rh_pericalcarine_thickness                           NaN
#           rh_postcentral_thickness                             NaN
#           rh_posteriorcingulate_thickness                      NaN
#           rh_precentral_thickness                              NaN
#           rh_precuneus_thickness                               NaN
#           rh_rostralanteriorcingulate_thickness                NaN
#           rh_rostralmiddlefrontal_thickness                    NaN
#           rh_superiorfrontal_thickness                         NaN
#           rh_superiorparietal_thickness                        NaN
#           rh_superiortemporal_thickness                        NaN
#           rh_supramarginal_thickness                           NaN
#           rh_frontalpole_thickness                             NaN
#           rh_temporalpole_thickness                            NaN
#           rh_transversetemporal_thickness                      NaN
#           rh_insula_thickness                                  NaN
#           rh_MeanThickness_thickness                           NaN
#           BrainSegVolNotVent                                   NaN
#           eTIV_y                                               NaN
#
#                                                  Left-Cerebellum-White-Matter  \
# Age
# 17.000000 SubjectID                                                       1.0
#           Height                                                          NaN
#           Weight                                                          NaN
#           Handedness                                                      NaN
#           Measure:volume                                                  NaN
#           Left-Lateral-Ventricle                                         -1.0
#           Left-Inf-Lat-Vent                                              -1.0
#           Left-Cerebellum-White-Matter                                    1.0
#           Left-Cerebellum-Cortex                                          1.0
#           Left-Thalamus-Proper                                           -1.0
#           Left-Caudate                                                   -1.0
#           Left-Putamen                                                   -1.0
#           Left-Pallidum                                                  -1.0
#           3rd-Ventricle                                                  -1.0
#           4th-Ventricle                                                  -1.0
#           Brain-Stem                                                     -1.0
#           Left-Hippocampus                                                1.0
#           Left-Amygdala                                                  -1.0
#           CSF                                                             1.0
#           Left-Accumbens-area                                            -1.0
#           Left-VentralDC                                                 -1.0
#           Left-vessel                                                    -1.0
#           Left-choroid-plexus                                             1.0
#           Right-Lateral-Ventricle                                        -1.0
#           Right-Inf-Lat-Vent                                              1.0
#           Right-Cerebellum-White-Matter                                   1.0
#           Right-Cerebellum-Cortex                                         1.0
#           Right-Thalamus-Proper                                          -1.0
#           Right-Caudate                                                  -1.0
#           Right-Putamen                                                  -1.0
# ...                                                                       ...
# 83.457906 rh_inferiortemporal_thickness                                   NaN
#           rh_isthmuscingulate_thickness                                   NaN
#           rh_lateraloccipital_thickness                                   NaN
#           rh_lateralorbitofrontal_thickness                               NaN
#           rh_lingual_thickness                                            NaN
#           rh_medialorbitofrontal_thickness                                NaN
#           rh_middletemporal_thickness                                     NaN
#           rh_parahippocampal_thickness                                    NaN
#           rh_paracentral_thickness                                        NaN
#           rh_parsopercularis_thickness                                    NaN
#           rh_parsorbitalis_thickness                                      NaN
#           rh_parstriangularis_thickness                                   NaN
#           rh_pericalcarine_thickness                                      NaN
#           rh_postcentral_thickness                                        NaN
#           rh_posteriorcingulate_thickness                                 NaN
#           rh_precentral_thickness                                         NaN
#           rh_precuneus_thickness                                          NaN
#           rh_rostralanteriorcingulate_thickness                           NaN
#           rh_rostralmiddlefrontal_thickness                               NaN
#           rh_superiorfrontal_thickness                                    NaN
#           rh_superiorparietal_thickness                                   NaN
#           rh_superiortemporal_thickness                                   NaN
#           rh_supramarginal_thickness                                      NaN
#           rh_frontalpole_thickness                                        NaN
#           rh_temporalpole_thickness                                       NaN
#           rh_transversetemporal_thickness                                 NaN
#           rh_insula_thickness                                             NaN
#           rh_MeanThickness_thickness                                      NaN
#           BrainSegVolNotVent                                              NaN
#           eTIV_y                                                          NaN
#
#                                                  Left-Cerebellum-Cortex  \
# Age
# 17.000000 SubjectID                                                 1.0
#           Height                                                    NaN
#           Weight                                                    NaN
#           Handedness                                                NaN
#           Measure:volume                                            NaN
#           Left-Lateral-Ventricle                                   -1.0
#           Left-Inf-Lat-Vent                                        -1.0
#           Left-Cerebellum-White-Matter                              1.0
#           Left-Cerebellum-Cortex                                    1.0
#           Left-Thalamus-Proper                                     -1.0
#           Left-Caudate                                             -1.0
#           Left-Putamen                                             -1.0
#           Left-Pallidum                                            -1.0
#           3rd-Ventricle                                            -1.0
#           4th-Ventricle                                            -1.0
#           Brain-Stem                                               -1.0
#           Left-Hippocampus                                          1.0
#           Left-Amygdala                                            -1.0
#           CSF                                                       1.0
#           Left-Accumbens-area                                      -1.0
#           Left-VentralDC                                           -1.0
#           Left-vessel                                              -1.0
#           Left-choroid-plexus                                       1.0
#           Right-Lateral-Ventricle                                  -1.0
#           Right-Inf-Lat-Vent                                        1.0
#           Right-Cerebellum-White-Matter                             1.0
#           Right-Cerebellum-Cortex                                   1.0
#           Right-Thalamus-Proper                                    -1.0
#           Right-Caudate                                            -1.0
#           Right-Putamen                                            -1.0
# ...                                                                 ...
# 83.457906 rh_inferiortemporal_thickness                             NaN
#           rh_isthmuscingulate_thickness                             NaN
#           rh_lateraloccipital_thickness                             NaN
#           rh_lateralorbitofrontal_thickness                         NaN
#           rh_lingual_thickness                                      NaN
#           rh_medialorbitofrontal_thickness                          NaN
#           rh_middletemporal_thickness                               NaN
#           rh_parahippocampal_thickness                              NaN
#           rh_paracentral_thickness                                  NaN
#           rh_parsopercularis_thickness                              NaN
#           rh_parsorbitalis_thickness                                NaN
#           rh_parstriangularis_thickness                             NaN
#           rh_pericalcarine_thickness                                NaN
#           rh_postcentral_thickness                                  NaN
#           rh_posteriorcingulate_thickness                           NaN
#           rh_precentral_thickness                                   NaN
#           rh_precuneus_thickness                                    NaN
#           rh_rostralanteriorcingulate_thickness                     NaN
#           rh_rostralmiddlefrontal_thickness                         NaN
#           rh_superiorfrontal_thickness                              NaN
#           rh_superiorparietal_thickness                             NaN
#           rh_superiortemporal_thickness                             NaN
#           rh_supramarginal_thickness                                NaN
#           rh_frontalpole_thickness                                  NaN
#           rh_temporalpole_thickness                                 NaN
#           rh_transversetemporal_thickness                           NaN
#           rh_insula_thickness                                       NaN
#           rh_MeanThickness_thickness                                NaN
#           BrainSegVolNotVent                                        NaN
#           eTIV_y                                                    NaN
#
#                                                  Left-Thalamus-Proper  ...  \
# Age                                                                    ...
# 17.000000 SubjectID                                              -1.0  ...
#           Height                                                  NaN  ...
#           Weight                                                  NaN  ...
#           Handedness                                              NaN  ...
#           Measure:volume                                          NaN  ...
#           Left-Lateral-Ventricle                                  1.0  ...
#           Left-Inf-Lat-Vent                                       1.0  ...
#           Left-Cerebellum-White-Matter                           -1.0  ...
#           Left-Cerebellum-Cortex                                 -1.0  ...
#           Left-Thalamus-Proper                                    1.0  ...
#           Left-Caudate                                            1.0  ...
#           Left-Putamen                                            1.0  ...
#           Left-Pallidum                                           1.0  ...
#           3rd-Ventricle                                           1.0  ...
#           4th-Ventricle                                           1.0  ...
#           Brain-Stem                                              1.0  ...
#           Left-Hippocampus                                       -1.0  ...
#           Left-Amygdala                                           1.0  ...
#           CSF                                                    -1.0  ...
#           Left-Accumbens-area                                     1.0  ...
#           Left-VentralDC                                          1.0  ...
#           Left-vessel                                             1.0  ...
#           Left-choroid-plexus                                    -1.0  ...
#           Right-Lateral-Ventricle                                 1.0  ...
#           Right-Inf-Lat-Vent                                     -1.0  ...
#           Right-Cerebellum-White-Matter                          -1.0  ...
#           Right-Cerebellum-Cortex                                -1.0  ...
#           Right-Thalamus-Proper                                   1.0  ...
#           Right-Caudate                                           1.0  ...
#           Right-Putamen                                           1.0  ...
# ...                                                               ...  ...
# 83.457906 rh_inferiortemporal_thickness                           NaN  ...
#           rh_isthmuscingulate_thickness                           NaN  ...
#           rh_lateraloccipital_thickness                           NaN  ...
#           rh_lateralorbitofrontal_thickness                       NaN  ...
#           rh_lingual_thickness                                    NaN  ...
#           rh_medialorbitofrontal_thickness                        NaN  ...
#           rh_middletemporal_thickness                             NaN  ...
#           rh_parahippocampal_thickness                            NaN  ...
#           rh_paracentral_thickness                                NaN  ...
#           rh_parsopercularis_thickness                            NaN  ...
#           rh_parsorbitalis_thickness                              NaN  ...
#           rh_parstriangularis_thickness                           NaN  ...
#           rh_pericalcarine_thickness                              NaN  ...
#           rh_postcentral_thickness                                NaN  ...
#           rh_posteriorcingulate_thickness                         NaN  ...
#           rh_precentral_thickness                                 NaN  ...
#           rh_precuneus_thickness                                  NaN  ...
#           rh_rostralanteriorcingulate_thickness                   NaN  ...
#           rh_rostralmiddlefrontal_thickness                       NaN  ...
#           rh_superiorfrontal_thickness                            NaN  ...
#           rh_superiorparietal_thickness                           NaN  ...
#           rh_superiortemporal_thickness                           NaN  ...
#           rh_supramarginal_thickness                              NaN  ...
#           rh_frontalpole_thickness                                NaN  ...
#           rh_temporalpole_thickness                               NaN  ...
#           rh_transversetemporal_thickness                         NaN  ...
#           rh_insula_thickness                                     NaN  ...
#           rh_MeanThickness_thickness                              NaN  ...
#           BrainSegVolNotVent                                      NaN  ...
#           eTIV_y                                                  NaN  ...
#
#                                                  rh_superiorparietal_thickness  \
# Age
# 17.000000 SubjectID                                                        1.0
#           Height                                                           NaN
#           Weight                                                           NaN
#           Handedness                                                       NaN
#           Measure:volume                                                   NaN
#           Left-Lateral-Ventricle                                          -1.0
#           Left-Inf-Lat-Vent                                               -1.0
#           Left-Cerebellum-White-Matter                                     1.0
#           Left-Cerebellum-Cortex                                           1.0
#           Left-Thalamus-Proper                                            -1.0
#           Left-Caudate                                                    -1.0
#           Left-Putamen                                                    -1.0
#           Left-Pallidum                                                   -1.0
#           3rd-Ventricle                                                   -1.0
#           4th-Ventricle                                                   -1.0
#           Brain-Stem                                                      -1.0
#           Left-Hippocampus                                                 1.0
#           Left-Amygdala                                                   -1.0
#           CSF                                                              1.0
#           Left-Accumbens-area                                             -1.0
#           Left-VentralDC                                                  -1.0
#           Left-vessel                                                     -1.0
#           Left-choroid-plexus                                              1.0
#           Right-Lateral-Ventricle                                         -1.0
#           Right-Inf-Lat-Vent                                               1.0
#           Right-Cerebellum-White-Matter                                    1.0
#           Right-Cerebellum-Cortex                                          1.0
#           Right-Thalamus-Proper                                           -1.0
#           Right-Caudate                                                   -1.0
#           Right-Putamen                                                   -1.0
# ...                                                                        ...
# 83.457906 rh_inferiortemporal_thickness                                    NaN
#           rh_isthmuscingulate_thickness                                    NaN
#           rh_lateraloccipital_thickness                                    NaN
#           rh_lateralorbitofrontal_thickness                                NaN
#           rh_lingual_thickness                                             NaN
#           rh_medialorbitofrontal_thickness                                 NaN
#           rh_middletemporal_thickness                                      NaN
#           rh_parahippocampal_thickness                                     NaN
#           rh_paracentral_thickness                                         NaN
#           rh_parsopercularis_thickness                                     NaN
#           rh_parsorbitalis_thickness                                       NaN
#           rh_parstriangularis_thickness                                    NaN
#           rh_pericalcarine_thickness                                       NaN
#           rh_postcentral_thickness                                         NaN
#           rh_posteriorcingulate_thickness                                  NaN
#           rh_precentral_thickness                                          NaN
#           rh_precuneus_thickness                                           NaN
#           rh_rostralanteriorcingulate_thickness                            NaN
#           rh_rostralmiddlefrontal_thickness                                NaN
#           rh_superiorfrontal_thickness                                     NaN
#           rh_superiorparietal_thickness                                    NaN
#           rh_superiortemporal_thickness                                    NaN
#           rh_supramarginal_thickness                                       NaN
#           rh_frontalpole_thickness                                         NaN
#           rh_temporalpole_thickness                                        NaN
#           rh_transversetemporal_thickness                                  NaN
#           rh_insula_thickness                                              NaN
#           rh_MeanThickness_thickness                                       NaN
#           BrainSegVolNotVent                                               NaN
#           eTIV_y                                                           NaN
#
#                                                  rh_superiortemporal_thickness  \
# Age
# 17.000000 SubjectID                                                        1.0
#           Height                                                           NaN
#           Weight                                                           NaN
#           Handedness                                                       NaN
#           Measure:volume                                                   NaN
#           Left-Lateral-Ventricle                                          -1.0
#           Left-Inf-Lat-Vent                                               -1.0
#           Left-Cerebellum-White-Matter                                     1.0
#           Left-Cerebellum-Cortex                                           1.0
#           Left-Thalamus-Proper                                            -1.0
#           Left-Caudate                                                    -1.0
#           Left-Putamen                                                    -1.0
#           Left-Pallidum                                                   -1.0
#           3rd-Ventricle                                                   -1.0
#           4th-Ventricle                                                   -1.0
#           Brain-Stem                                                      -1.0
#           Left-Hippocampus                                                 1.0
#           Left-Amygdala                                                   -1.0
#           CSF                                                              1.0
#           Left-Accumbens-area                                             -1.0
#           Left-VentralDC                                                  -1.0
#           Left-vessel                                                     -1.0
#           Left-choroid-plexus                                              1.0
#           Right-Lateral-Ventricle                                         -1.0
#           Right-Inf-Lat-Vent                                               1.0
#           Right-Cerebellum-White-Matter                                    1.0
#           Right-Cerebellum-Cortex                                          1.0
#           Right-Thalamus-Proper                                           -1.0
#           Right-Caudate                                                   -1.0
#           Right-Putamen                                                   -1.0
# ...                                                                        ...
# 83.457906 rh_inferiortemporal_thickness                                    NaN
#           rh_isthmuscingulate_thickness                                    NaN
#           rh_lateraloccipital_thickness                                    NaN
#           rh_lateralorbitofrontal_thickness                                NaN
#           rh_lingual_thickness                                             NaN
#           rh_medialorbitofrontal_thickness                                 NaN
#           rh_middletemporal_thickness                                      NaN
#           rh_parahippocampal_thickness                                     NaN
#           rh_paracentral_thickness                                         NaN
#           rh_parsopercularis_thickness                                     NaN
#           rh_parsorbitalis_thickness                                       NaN
#           rh_parstriangularis_thickness                                    NaN
#           rh_pericalcarine_thickness                                       NaN
#           rh_postcentral_thickness                                         NaN
#           rh_posteriorcingulate_thickness                                  NaN
#           rh_precentral_thickness                                          NaN
#           rh_precuneus_thickness                                           NaN
#           rh_rostralanteriorcingulate_thickness                            NaN
#           rh_rostralmiddlefrontal_thickness                                NaN
#           rh_superiorfrontal_thickness                                     NaN
#           rh_superiorparietal_thickness                                    NaN
#           rh_superiortemporal_thickness                                    NaN
#           rh_supramarginal_thickness                                       NaN
#           rh_frontalpole_thickness                                         NaN
#           rh_temporalpole_thickness                                        NaN
#           rh_transversetemporal_thickness                                  NaN
#           rh_insula_thickness                                              NaN
#           rh_MeanThickness_thickness                                       NaN
#           BrainSegVolNotVent                                               NaN
#           eTIV_y                                                           NaN
#
#                                                  rh_supramarginal_thickness  \
# Age
# 17.000000 SubjectID                                                     1.0
#           Height                                                        NaN
#           Weight                                                        NaN
#           Handedness                                                    NaN
#           Measure:volume                                                NaN
#           Left-Lateral-Ventricle                                       -1.0
#           Left-Inf-Lat-Vent                                            -1.0
#           Left-Cerebellum-White-Matter                                  1.0
#           Left-Cerebellum-Cortex                                        1.0
#           Left-Thalamus-Proper                                         -1.0
#           Left-Caudate                                                 -1.0
#           Left-Putamen                                                 -1.0
#           Left-Pallidum                                                -1.0
#           3rd-Ventricle                                                -1.0
#           4th-Ventricle                                                -1.0
#           Brain-Stem                                                   -1.0
#           Left-Hippocampus                                              1.0
#           Left-Amygdala                                                -1.0
#           CSF                                                           1.0
#           Left-Accumbens-area                                          -1.0
#           Left-VentralDC                                               -1.0
#           Left-vessel                                                  -1.0
#           Left-choroid-plexus                                           1.0
#           Right-Lateral-Ventricle                                      -1.0
#           Right-Inf-Lat-Vent                                            1.0
#           Right-Cerebellum-White-Matter                                 1.0
#           Right-Cerebellum-Cortex                                       1.0
#           Right-Thalamus-Proper                                        -1.0
#           Right-Caudate                                                -1.0
#           Right-Putamen                                                -1.0
# ...                                                                     ...
# 83.457906 rh_inferiortemporal_thickness                                 NaN
#           rh_isthmuscingulate_thickness                                 NaN
#           rh_lateraloccipital_thickness                                 NaN
#           rh_lateralorbitofrontal_thickness                             NaN
#           rh_lingual_thickness                                          NaN
#           rh_medialorbitofrontal_thickness                              NaN
#           rh_middletemporal_thickness                                   NaN
#           rh_parahippocampal_thickness                                  NaN
#           rh_paracentral_thickness                                      NaN
#           rh_parsopercularis_thickness                                  NaN
#           rh_parsorbitalis_thickness                                    NaN
#           rh_parstriangularis_thickness                                 NaN
#           rh_pericalcarine_thickness                                    NaN
#           rh_postcentral_thickness                                      NaN
#           rh_posteriorcingulate_thickness                               NaN
#           rh_precentral_thickness                                       NaN
# ...
#           rh_pericalcarine_thickness                                         NaN
#           rh_postcentral_thickness                                           NaN
#           rh_posteriorcingulate_thickness                                    NaN
#           rh_precentral_thickness                                            NaN
#           rh_precuneus_thickness                                             NaN
#           rh_rostralanteriorcingulate_thickness                              NaN
#           rh_rostralmiddlefrontal_thickness                                  NaN
#           rh_superiorfrontal_thickness                                       NaN
#           rh_superiorparietal_thickness                                      NaN
#           rh_superiortemporal_thickness                                      NaN
#           rh_supramarginal_thickness                                         NaN
#           rh_frontalpole_thickness                                           NaN
#           rh_temporalpole_thickness                                          NaN
#           rh_transversetemporal_thickness                                    NaN
#           rh_insula_thickness                                                NaN
#           rh_MeanThickness_thickness                                         NaN
#           BrainSegVolNotVent                                                 NaN
#           eTIV_y                                                             NaN
#
#                                                  rh_insula_thickness  \
# Age
# 17.000000 SubjectID                                              1.0
#           Height                                                 NaN
#           Weight                                                 NaN
#           Handedness                                             NaN
#           Measure:volume                                         NaN
#           Left-Lateral-Ventricle                                -1.0
#           Left-Inf-Lat-Vent                                     -1.0
#           Left-Cerebellum-White-Matter                           1.0
#           Left-Cerebellum-Cortex                                 1.0
#           Left-Thalamus-Proper                                  -1.0
#           Left-Caudate                                          -1.0
#           Left-Putamen                                          -1.0
#           Left-Pallidum                                         -1.0
#           3rd-Ventricle                                         -1.0
#           4th-Ventricle                                         -1.0
#           Brain-Stem                                            -1.0
#           Left-Hippocampus                                       1.0
#           Left-Amygdala                                         -1.0
#           CSF                                                    1.0
#           Left-Accumbens-area                                   -1.0
#           Left-VentralDC                                        -1.0
#           Left-vessel                                           -1.0
#           Left-choroid-plexus                                    1.0
#           Right-Lateral-Ventricle                               -1.0
#           Right-Inf-Lat-Vent                                     1.0
#           Right-Cerebellum-White-Matter                          1.0
#           Right-Cerebellum-Cortex                                1.0
#           Right-Thalamus-Proper                                 -1.0
#           Right-Caudate                                         -1.0
#           Right-Putamen                                         -1.0
# ...                                                              ...
# 83.457906 rh_inferiortemporal_thickness                          NaN
#           rh_isthmuscingulate_thickness                          NaN
#           rh_lateraloccipital_thickness                          NaN
#           rh_lateralorbitofrontal_thickness                      NaN
#           rh_lingual_thickness                                   NaN
#           rh_medialorbitofrontal_thickness                       NaN
#           rh_middletemporal_thickness                            NaN
#           rh_parahippocampal_thickness                           NaN
#           rh_paracentral_thickness                               NaN
#           rh_parsopercularis_thickness                           NaN
#           rh_parsorbitalis_thickness                             NaN
#           rh_parstriangularis_thickness                          NaN
#           rh_pericalcarine_thickness                             NaN
#           rh_postcentral_thickness                               NaN
#           rh_posteriorcingulate_thickness                        NaN
#           rh_precentral_thickness                                NaN
#           rh_precuneus_thickness                                 NaN
#           rh_rostralanteriorcingulate_thickness                  NaN
#           rh_rostralmiddlefrontal_thickness                      NaN
#           rh_superiorfrontal_thickness                           NaN
#           rh_superiorparietal_thickness                          NaN
#           rh_superiortemporal_thickness                          NaN
#           rh_supramarginal_thickness                             NaN
#           rh_frontalpole_thickness                               NaN
#           rh_temporalpole_thickness                              NaN
#           rh_transversetemporal_thickness                        NaN
#           rh_insula_thickness                                    NaN
#           rh_MeanThickness_thickness                             NaN
#           BrainSegVolNotVent                                     NaN
#           eTIV_y                                                 NaN
#
#                                                  rh_MeanThickness_thickness  \
# Age
# 17.000000 SubjectID                                                     1.0
#           Height                                                        NaN
#           Weight                                                        NaN
#           Handedness                                                    NaN
#           Measure:volume                                                NaN
#           Left-Lateral-Ventricle                                       -1.0
#           Left-Inf-Lat-Vent                                            -1.0
#           Left-Cerebellum-White-Matter                                  1.0
#           Left-Cerebellum-Cortex                                        1.0
#           Left-Thalamus-Proper                                         -1.0
#           Left-Caudate                                                 -1.0
#           Left-Putamen                                                 -1.0
#           Left-Pallidum                                                -1.0
#           3rd-Ventricle                                                -1.0
#           4th-Ventricle                                                -1.0
#           Brain-Stem                                                   -1.0
#           Left-Hippocampus                                              1.0
#           Left-Amygdala                                                -1.0
#           CSF                                                           1.0
#           Left-Accumbens-area                                          -1.0
#           Left-VentralDC                                               -1.0
#           Left-vessel                                                  -1.0
#           Left-choroid-plexus                                           1.0
#           Right-Lateral-Ventricle                                      -1.0
#           Right-Inf-Lat-Vent                                            1.0
#           Right-Cerebellum-White-Matter                                 1.0
#           Right-Cerebellum-Cortex                                       1.0
#           Right-Thalamus-Proper                                        -1.0
#           Right-Caudate                                                -1.0
#           Right-Putamen                                                -1.0
# ...                                                                     ...
# 83.457906 rh_inferiortemporal_thickness                                 NaN
#           rh_isthmuscingulate_thickness                                 NaN
#           rh_lateraloccipital_thickness                                 NaN
#           rh_lateralorbitofrontal_thickness                             NaN
#           rh_lingual_thickness                                          NaN
#           rh_medialorbitofrontal_thickness                              NaN
#           rh_middletemporal_thickness                                   NaN
#           rh_parahippocampal_thickness                                  NaN
#           rh_paracentral_thickness                                      NaN
#           rh_parsopercularis_thickness                                  NaN
#           rh_parsorbitalis_thickness                                    NaN
#           rh_parstriangularis_thickness                                 NaN
#           rh_pericalcarine_thickness                                    NaN
#           rh_postcentral_thickness                                      NaN
#           rh_posteriorcingulate_thickness                               NaN
#           rh_precentral_thickness                                       NaN
#           rh_precuneus_thickness                                        NaN
#           rh_rostralanteriorcingulate_thickness                         NaN
#           rh_rostralmiddlefrontal_thickness                             NaN
#           rh_superiorfrontal_thickness                                  NaN
#           rh_superiorparietal_thickness                                 NaN
#           rh_superiortemporal_thickness                                 NaN
#           rh_supramarginal_thickness                                    NaN
#           rh_frontalpole_thickness                                      NaN
#           rh_temporalpole_thickness                                     NaN
#           rh_transversetemporal_thickness                               NaN
#           rh_insula_thickness                                           NaN
#           rh_MeanThickness_thickness                                    NaN
#           BrainSegVolNotVent                                            NaN
#           eTIV_y                                                        NaN
#
#                                                  BrainSegVolNotVent  eTIV_y
# Age
# 17.000000 SubjectID                                            -1.0    -1.0
#           Height                                                NaN     NaN
#           Weight                                                NaN     NaN
#           Handedness                                            NaN     NaN
#           Measure:volume                                        NaN     NaN
#           Left-Lateral-Ventricle                                1.0     1.0
#           Left-Inf-Lat-Vent                                     1.0     1.0
#           Left-Cerebellum-White-Matter                         -1.0    -1.0
#           Left-Cerebellum-Cortex                               -1.0    -1.0
#           Left-Thalamus-Proper                                  1.0     1.0
#           Left-Caudate                                          1.0     1.0
#           Left-Putamen                                          1.0     1.0
#           Left-Pallidum                                         1.0     1.0
#           3rd-Ventricle                                         1.0     1.0
#           4th-Ventricle                                         1.0     1.0
#           Brain-Stem                                            1.0     1.0
#           Left-Hippocampus                                     -1.0    -1.0
#           Left-Amygdala                                         1.0     1.0
#           CSF                                                  -1.0    -1.0
#           Left-Accumbens-area                                   1.0     1.0
#           Left-VentralDC                                        1.0     1.0
#           Left-vessel                                           1.0     1.0
#           Left-choroid-plexus                                  -1.0    -1.0
#           Right-Lateral-Ventricle                               1.0     1.0
#           Right-Inf-Lat-Vent                                   -1.0    -1.0
#           Right-Cerebellum-White-Matter                        -1.0    -1.0
#           Right-Cerebellum-Cortex                              -1.0    -1.0
#           Right-Thalamus-Proper                                 1.0     1.0
#           Right-Caudate                                         1.0     1.0
#           Right-Putamen                                         1.0     1.0
# ...                                                             ...     ...
# 83.457906 rh_inferiortemporal_thickness                         NaN     NaN
#           rh_isthmuscingulate_thickness                         NaN     NaN
#           rh_lateraloccipital_thickness                         NaN     NaN
#           rh_lateralorbitofrontal_thickness                     NaN     NaN
#           rh_lingual_thickness                                  NaN     NaN
#           rh_medialorbitofrontal_thickness                      NaN     NaN
#           rh_middletemporal_thickness                           NaN     NaN
#           rh_parahippocampal_thickness                          NaN     NaN
#           rh_paracentral_thickness                              NaN     NaN
#           rh_parsopercularis_thickness                          NaN     NaN
#           rh_parsorbitalis_thickness                            NaN     NaN
#           rh_parstriangularis_thickness                         NaN     NaN
#           rh_pericalcarine_thickness                            NaN     NaN
#           rh_postcentral_thickness                              NaN     NaN
#           rh_posteriorcingulate_thickness                       NaN     NaN
#           rh_precentral_thickness                               NaN     NaN
#           rh_precuneus_thickness                                NaN     NaN
#           rh_rostralanteriorcingulate_thickness                 NaN     NaN
#           rh_rostralmiddlefrontal_thickness                     NaN     NaN
#           rh_superiorfrontal_thickness                          NaN     NaN
#           rh_superiorparietal_thickness                         NaN     NaN
#           rh_superiortemporal_thickness                         NaN     NaN
#           rh_supramarginal_thickness                            NaN     NaN
#           rh_frontalpole_thickness                              NaN     NaN
#           rh_temporalpole_thickness                             NaN     NaN
#           rh_transversetemporal_thickness                       NaN     NaN
#           rh_insula_thickness                                   NaN     NaN
#           rh_MeanThickness_thickness                            NaN     NaN
#           BrainSegVolNotVent                                    NaN     NaN
#           eTIV_y                                                NaN     NaN
#
# [62785 rows x 145 columns]

# %% [markdown]
# DataFrame has an `assign()` method that allows you to easily create new columns that are potentially derived from existing columns.

# %%
iris.assign(sepal_ratio = iris['SepalWidth'] / iris['SepalLength']).head().round(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name  sepal_ratio
# 0          5.1         3.5          1.4         0.2  Iris-setosa        0.686
# 1          4.9         3.0          1.4         0.2  Iris-setosa        0.612
# 2          4.7         3.2          1.3         0.2  Iris-setosa        0.681
# 3          4.6         3.1          1.5         0.2  Iris-setosa        0.674
# 4          5.0         3.6          1.4         0.2  Iris-setosa        0.720

# %% [markdown]
# In the example above, we inserted a precomputed value. <br>
# We can also pass in a function of one argument to be evaluated on the DataFrame being assigned to.

# %%
iris.assign(sepal_ratio = lambda x: (x['SepalWidth'] /
                                     x['SepalLength'])).head().round(3)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name  sepal_ratio
# 0          5.1         3.5          1.4         0.2  Iris-setosa        0.686
# 1          4.9         3.0          1.4         0.2  Iris-setosa        0.612
# 2          4.7         3.2          1.3         0.2  Iris-setosa        0.681
# 3          4.6         3.1          1.5         0.2  Iris-setosa        0.674
# 4          5.0         3.6          1.4         0.2  Iris-setosa        0.720

# %% [markdown]
# `assign` always returns a copy of the data, leaving the original DataFrame untouched, e.g.

# %%
iris.head(2)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa

# %% [markdown]
# Passing a callable, as opposed to an actual value to be inserted, is useful when you don’t have a reference to the DataFrame at hand. This is common when using assign``  in a chain of operations. For example, we can limit the DataFrame to just those observations with a Sepal Length greater than 5, calculate the ratio, and plot:

# %%
(iris.query('SepalLength > 5')
 .assign(SepalRatio = lambda x: x.SepalWidth / x.SepalLength,
         PetalRatio = lambda x: x.PetalWidth / x.PetalLength)
 .plot(kind='scatter', x='SepalRatio', y='PetalRatio'))

# %% [markdown]
# ### Classification

# %% [markdown]
# *Organizing data as X and y before classification*

# %%
from sklearn.preprocessing import LabelEncoder

# dfX5Y = pd.read_csv('../results/02_X5Y.csv', sep=',')
# print(dfX5Y.info())
# print(dfX5Y.describe())
# dfX5Y

# Featuer importance XGBoost:
# X = df.loc[:, ['CC_Mid_Anterior_w3', 'BrainSegVol-to-eTIV_w3', 'CSF_w2']] # Top three important features
# Featuer importance RF (Strrop_3):
X = df.loc[:, ['BrainSegVol-to-eTIV_w3', 'CC_Mid_Anterior_w3', 'ic04-ic02']] # Top three important features
# Featuer importance RF predicrting Stroop_1_R_3:
# X = df.loc[:, ['ic09-ic06', 'ic10-ic01', 'ic05-ic03']] # Top three important features
# Featuer importance RF predicrting Stroop_2_R_3:
# X = df.loc[:, ['WM-hypointensities_w3', 'ic17-ic04', 'Left-vessel_w3']] # Top three important features
# X = df.loc[:, ['BrainSegVol-to-eTIV_w3', 'ic04-ic02']] # Two important features
# X = df.loc[:, ['BrainSegVol-to-eTIV_w3', 'CC_Mid_Anterior_w3']] # Top two important features
Y = df.loc[:, ['Stroop_3_cat']]
y = Y.as_matrix().ravel()
np.unique(y)
X.columns

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import preprocessing

# X = dfX5Y.loc[:, dfX5Y.columns != 'grp']      # Top five important connections
# X = dfX5Y.loc[:, ['ic09-ic02', 'ic04-ic01']]   # Top two important connections
# X = df.loc[:, ['LatVent_w2', 'LatVent_w3', 'ic09-ic02', 'ic04-ic01']]
# X = df.loc[:, ['LatVent_w3', 'ic09-ic02']]
# X = df.loc[:, ['LatVent_w2', 'LatVent_w3']]
# Y = df.loc[:, ['Stroop_3_cat']]

# X = df.loc[:, ['BrainSegVol-to-eTIV_w3', 'CC_Mid_Anterior_w3', 'ic04-ic02']]
# Y = df.loc[:, ['Stroop_3_cat']]
# y = Y.as_matrix().ravel()

rs = 42 # random_state (42)
hls = 3 # MLP hidden layer size (3 or 4)
# https://stackoverflow.com/questions/37659970/how-does-sklearn-compute-the-precision-score-metric
myaverage = 'weighted' # For multilabel classification  'micro', 'macro', 'samples', 'weighted'
# see: https://stackoverflow.com/questions/37659970/how-does-sklearn-compute-the-precision-score-metric

# http://scikit-learn.org/stable/modules/neural_networks_supervised.html
# Class MLPClassifier implements a multi-layer perceptron (MLP) algorithm that 
# trains using Backpropagation.

# So what about size of the hidden layer(s)--how many neurons? 
# There are some empirically-derived rules-of-thumb, of these, the most 
# commonly relied on is 'the optimal size of the hidden layer is usually 
# between the size of the input and size of the output layers'. 
# Jeff Heaton, author of Introduction to Neural Networks in Java offers a few more.
#
# In sum, for most problems, one could probably get decent performance (even without 
# a second optimization step) by setting the hidden layer configuration using j
# ust two rules: 
#  (i) number of hidden layers equals one; and 
# (ii) the number of neurons in that layer is the mean of the neurons in the 
#      input and output layers.
# Compute the precision
# The precision is the ratio tp / (tp + fp) where tp is the number of true positives and 
# fp the number of false positives. The precision is intuitively the ability of the 
# classifier not to label as positive a sample that is negative.

# Compute the recall
# The recall is the ratio tp / (tp + fn) where tp is the number of true positives and 
# fn the number of false negatives. The recall is intuitively the ability of the 
# classifier to find all the positive samples.

# Compute the F1 score, also known as balanced F-score or F-measure
# The F1 score can be interpreted as a weighted average of the precision and recall, 
# where an F1 score reaches its best value at 1 and worst score at 0. 
# The relative contribution of precision and recall to the F1 score are equal. 
# The formula for the F1 score is:
#    F1 = 2 * (precision * recall) / (precision + recall)
# In the multi-class and multi-label case, this is the weighted average of the F1 score of each class.

pipe_clf1 = Pipeline([
    ('scl', StandardScaler()),
    #('pca', PCA(n_components=2)),
    ('clf1', LogisticRegression(C=1., solver='saga', n_jobs=1, 
                                multi_class='multinomial', random_state=rs))])

pipe_clf2 = Pipeline([
    ('scl', StandardScaler()),
    #('pca', PCA(n_components=2)),
    ('clf2', MLPClassifier(hidden_layer_sizes=(hls, ),   # =(100, )  ; =(4, )
                          activation='relu', solver='adam',
                          alpha=0.0001, batch_size='auto', learning_rate='constant',
                          learning_rate_init=0.001, power_t=0.5, max_iter=5000,
                          shuffle=True, random_state=rs, tol=0.0001, verbose=False,
                          warm_start=False, momentum=0.9, nesterovs_momentum=True,
                          early_stopping=False, validation_fraction=0.1,
                          beta_1=0.9, beta_2=0.999, epsilon=1e-08))])

# pipe_clf3 = Pipeline([
#     ('scl', StandardScaler()),
#     #('pca', PCA(n_components=2)),
#     ('clf3', RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None,
#                                   min_samples_split=2, min_samples_leaf=1,
#                                   min_weight_fraction_leaf=0.0, max_features='auto',
#                                   max_leaf_nodes=None,     #  min_impurity_split=1e-07,
#                                   bootstrap=True, oob_score=False, n_jobs=1,
#                                   random_state=rs, verbose=0, warm_start=False,
#                                   class_weight=None))])
# pipe_clf3 = Pipeline([
#     ('scl', StandardScaler()),
#     #('pca', PCA(n_components=2)),
#     ('clf3', GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#                                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                                         presort='auto', random_state=rs, subsample=1.0, verbose=0,
#                                         warm_start=False)

pipe_clf3 = Pipeline([
    ('scl', StandardScaler()),
    #('pca', PCA(n_components=2)),
    ('clf3', XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
                           gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
                           min_child_weight=1, missing=None, n_estimators=1000, nthread=-1,
                           objective='multi:softprob', reg_alpha=0, reg_lambda=1,
                           scale_pos_weight=1, seed=rs, silent=True, subsample=1))])
     
pipe_clf4 = Pipeline([
    ('scl', StandardScaler()),
    #('pca', PCA(n_components=2)),
    ('clf4', SVC(C=1.0, probability=True, random_state=rs))])
#    ('clf4', SVC(C=1.0, random_state=rs))])
    
pipe_clf5 = Pipeline([
    ('scl', StandardScaler()),
    #('pca', PCA(n_components=2)),
    ('clf5', KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='kd_tree', 
                           leaf_size=30, p=2, metric='minkowski', 
                           metric_params=None, n_jobs=1))])

pipe_clf_vote =  Pipeline([
#    ('scl', StandardScaler()),
    ('clf_vote', VotingClassifier(
        estimators=[('lr', pipe_clf1), 
                 ('mlp', pipe_clf2),
                 ('rf', pipe_clf3),
                 ('svc', pipe_clf4),
                 ('knn', pipe_clf5)],
     voting = 'soft'))])
#     voting = 'hard'))])

scores1_acc, scores2_acc, scores3_acc, scores4_acc, scores5_acc, scores_vote_acc = [], [], [], [], [], []
scores1_pre, scores2_pre, scores3_pre, scores4_pre, scores5_pre, scores_vote_pre = [], [], [], [], [], []
scores1_rec, scores2_rec, scores3_rec, scores4_rec, scores5_rec, scores_vote_rec = [], [], [], [], [], []
scores1_f1, scores2_f1, scores3_f1, scores4_f1, scores5_f1, scores_vote_f1 = [], [], [], [], [], []

n_splits = 10  # k=10
# n_splits = X.shape[0]   # i.e.  Leave One Out strategy
# for train_index, test_index in LeaveOneOut.split(X):

k=1
for train_index, test_index in \
StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=rs).split(X,y):
    print("Fold number:", k)
    #print("\nTRUE class:\n", list(y[test_index]))
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    
    #clf1 = LogisticRegression
    print(" - LogisticRegression")
    pipe_clf1.fit(X_train, y_train)
    scores1_acc.append(accuracy_score(y_test, pipe_clf1.predict(X_test)))
    scores1_pre.append(precision_score(y_test, pipe_clf1.predict(X_test), average=myaverage))
    scores1_rec.append(recall_score(y_test, pipe_clf1.predict(X_test), average=myaverage))
    scores1_f1.append(f1_score(y_test, pipe_clf1.predict(X_test), average=myaverage))
    print('    Precision: %.2f' % (precision_score(y_test, pipe_clf1.predict(X_test), average=myaverage)))
    print('    Recall: %.2f' % (recall_score(y_test, pipe_clf1.predict(X_test), average=myaverage)))
    #print("LR predicted:\n", list(pipe_clf1.predict(X_test)))
    
    #clf2 = MLPClassifier
    print(" - MLPClassifier")
    pipe_clf2.fit(X_train, y_train)
    scores2_acc.append(accuracy_score(y_test, pipe_clf2.predict(X_test)))
    scores2_pre.append(precision_score(y_test, pipe_clf2.predict(X_test), average=myaverage))
    scores2_rec.append(recall_score(y_test, pipe_clf2.predict(X_test), average=myaverage))
    scores2_f1.append(f1_score(y_test, pipe_clf2.predict(X_test), average=myaverage))
    print('    Precision: %.2f' % (precision_score(y_test, pipe_clf2.predict(X_test), average=myaverage)))
    print('    Recall: %.2f' % (recall_score(y_test, pipe_clf2.predict(X_test), average=myaverage)))
    #print("MLP predicted:\n", list(pipe_clf2.predict(X_test)))
    
    #clf3 = RandomForestClassifier
    #print(" - RandomForestClassifier")
    #clf3 = XGBoost
    print(" - XGBoost")
    pipe_clf3.fit(X_train, y_train)
    scores3_acc.append(accuracy_score(y_test, pipe_clf3.predict(X_test)))
    scores3_pre.append(precision_score(y_test, pipe_clf3.predict(X_test), average=myaverage))
    scores3_rec.append(recall_score(y_test, pipe_clf3.predict(X_test), average=myaverage))
    scores3_f1.append(f1_score(y_test, pipe_clf3.predict(X_test), average=myaverage))
    print('    Precision: %.2f' % (precision_score(y_test, pipe_clf3.predict(X_test), average=myaverage)))
    print('    Recall: %.2f' % (recall_score(y_test, pipe_clf3.predict(X_test), average=myaverage)))
    #print("RF predicted:\n", list(pipe_clf3.predict(X_test)))
    #print("XGB predicted:\n", list(pipe_clf3.predict(X_test)))
    
    #clf4 = svm.SVC()
    print(" - svm/SVC")
    pipe_clf4.fit(X_train, y_train)
    scores4_acc.append(accuracy_score(y_test, pipe_clf4.predict(X_test)))
    scores4_pre.append(precision_score(y_test, pipe_clf4.predict(X_test), average=myaverage))
    scores4_rec.append(recall_score(y_test, pipe_clf4.predict(X_test), average=myaverage))
    scores4_f1.append(f1_score(y_test, pipe_clf4.predict(X_test), average=myaverage))
    print('    Precision: %.2f' % (precision_score(y_test, pipe_clf4.predict(X_test), average=myaverage)))
    print('    Recall: %.2f' % (recall_score(y_test, pipe_clf4.predict(X_test), average=myaverage)))
    #print("SVM predicted:\n", list(pipe_clf4.predict(X_test)))
    
        #clf5 = KNeighborsClassifier
    print(" - KNN")
    pipe_clf5.fit(X_train, y_train)
    scores5_acc.append(accuracy_score(y_test, pipe_clf5.predict(X_test)))
    scores5_pre.append(precision_score(y_test, pipe_clf5.predict(X_test), average=myaverage))
    scores5_rec.append(recall_score(y_test, pipe_clf5.predict(X_test), average=myaverage))
    scores5_f1.append(f1_score(y_test, pipe_clf5.predict(X_test), average=myaverage))
    #print("KNN predicted:\n", list(pipe_clf5.predict(X_test)))
    
    #clf_vote = VotingClassifier
    print(" - VotingClassifier")
    pipe_clf_vote.fit(X_train, y_train)
    scores_vote_acc.append(accuracy_score(y_test, pipe_clf_vote.predict(X_test)))
    scores_vote_pre.append(precision_score(y_test, pipe_clf_vote.predict(X_test), average=myaverage))
    scores_vote_rec.append(recall_score(y_test, pipe_clf_vote.predict(X_test), average=myaverage))
    scores_vote_f1.append(f1_score(y_test, pipe_clf_vote.predict(X_test), average=myaverage))
    print('    Precision: %.2f' % (precision_score(y_test, pipe_clf_vote.predict(X_test), average=myaverage)))
    print('    Recall: %.2f' % (recall_score(y_test, pipe_clf_vote.predict(X_test), average=myaverage)))
    k=k+1
    
print('\nPredictors:')
print('X.columns = %s' % list(X.columns))

print('\nOutcome:')
print(pd.qcut(df['Stroop_3_R_3'], 3).head(0))
print(np.unique(y))

print('\nSome hyperparameters:')
print("MLP hidden_layer_size = %d" % (hls))
print("random_state = %d" % (rs))
print("score average = '%s'" % (myaverage))

print("\nLR : CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores1_acc), np.std(scores1_acc), n_splits))
print("MLP: CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores2_acc), np.std(scores2_acc), n_splits))
# print("RF : CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores3_acc), np.std(scores3_acc), n_splits))
print("XGB : CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores3_acc), np.std(scores3_acc), n_splits))
print("SVM: CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores4_acc), np.std(scores4_acc), n_splits))
print("KNN: CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores5_acc), np.std(scores5_acc), n_splits))
print("Voting: CV accuracy = %.3f +-%.3f (k=%d)" % (np.mean(scores_vote_acc), np.std(scores_vote_acc), n_splits))

print("\nLR : CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores1_pre), np.std(scores1_pre), n_splits))
print("MLP: CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores2_pre), np.std(scores2_pre), n_splits))
print("XGB : CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores3_pre), np.std(scores3_pre), n_splits))
print("SVM: CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores4_pre), np.std(scores4_pre), n_splits))
print("KNN: CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores5_pre), np.std(scores5_pre), n_splits))
print("Voting: CV precision = %.3f +-%.3f (k=%d)" % (np.mean(scores_vote_pre), np.std(scores_vote_pre), n_splits))

print("\nLR : CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores1_rec), np.std(scores1_rec), n_splits))
print("MLP: CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores2_rec), np.std(scores2_rec), n_splits))
print("XGB : CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores3_rec), np.std(scores3_rec), n_splits))
print("SVM: CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores4_rec), np.std(scores4_rec), n_splits))
print("KNN: CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores5_rec), np.std(scores5_rec), n_splits))
print("Voting: CV recall = %.3f +-%.3f (k=%d)" % (np.mean(scores_vote_rec), np.std(scores_vote_rec), n_splits))

print("\nLR : CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores1_f1), np.std(scores1_f1), n_splits))
print("MLP: CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores2_f1), np.std(scores2_f1), n_splits))
print("XGB : CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores3_f1), np.std(scores3_f1), n_splits))
print("SVM: CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores4_f1), np.std(scores4_f1), n_splits))
print("KNN: CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores5_f1), np.std(scores5_f1), n_splits))
print("Voting: CV F1-score = %.3f +-%.3f (k=%d)" % (np.mean(scores_vote_f1), np.std(scores_vote_f1), n_splits))
